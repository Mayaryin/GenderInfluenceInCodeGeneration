# %% [markdown]
# # Multivariate Analysis
# correlate
# - age
# - years of experience
# - normalized count of personal pronouns
# - normalized count of "and"
# - inv_inf score
# - prompt length
# - please (present / not present)
#
# with
# - pylint score
# - radon complexity

# %%
#
