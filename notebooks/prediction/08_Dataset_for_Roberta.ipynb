# %% [markdown]
# # Preparing the data for Roberta Finetuning
# - exporting two datasets:
#     - fully corrected
#     - raw prompts wihtout the ones in german and italian
# - both contain original punctuation

# %%
import sqlite3
import pandas as pd

conn  = sqlite3.connect('../../giicg.db')
expanded_prompts = pd.read_sql("Select * from expanded_prompts", conn).drop_duplicates(subset=['conversational'])
filtered_prompts = pd.read_sql(
    """
    SELECT
        fp.*,
        ep.language
    FROM
        filtered_prompts fp
    JOIN
        expanded_prompts ep
    ON
        fp.message_id = ep.message_id
    """,
    conn
).drop_duplicates(subset=['conversational'])

expanded_prompts
# Out:
#      message_id  conversation_id  role  \
# 0             1                1  user
# 1           730               32  user
# 2          1133               55  user
# 3          1135               55  user
# 4          1137               55  user
# ..          ...              ...   ...
# 748        1646               82  user
# 749        1845               37  user
# 750        1847               37  user
# 751        1849                2  user
# 752        1851                2  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 748  def run_query(query, n_results):\n    query_em...
# 749  \n        nun möchte ich judgement balancing m...
# 750  \n    ich sehe keine veränderung im Plot. Was ...
# 751  \n    I am working on the problem of reconstru...
# 752  \n        Focus on one step at the time. Write...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 748  this is my code. I want to: Get nodes and edge...
# 749  Now I want to bring judgement balancing into t...
# 750               I do not see any change in the plot.
# 751  \n    I am working on the problem of reconstru...
# 752  Focus on one step at the time. Write what is t...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 748  def run_query(query, n_results):\n    query_em...
# 749
# 750
# 751
# 752
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 748                                                       Man (cisgender)
# 749                                                     Woman (cisgender)
# 750                                                     Woman (cisgender)
# 751  Classic CV - Drone navigation\nIf you ever tho...    Man (cisgender)
# 752                                                       Man (cisgender)
#
#      user_id language
# 0          6       en
# 1          6       en
# 2          6       en
# 3          6       en
# 4          6       en
# ..       ...      ...
# 748       92       en
# 749       29       de
# 750       29       de
# 751        8       en
# 752        8       en
#
# [753 rows x 10 columns]

# %% [markdown]
# ## Filter and Clean

# %%
from helpers.normalization import remove_newlines

expanded_prompts = expanded_prompts[expanded_prompts['gender'].isin(['Woman (cisgender)', 'Man (cisgender)'])].reset_index()
expanded_prompts['conversational']  = expanded_prompts['conversational'].apply(remove_newlines)

filtered_prompts = filtered_prompts[filtered_prompts['language'] == 'en'].reset_index(drop=True)
filtered_prompts = filtered_prompts[filtered_prompts['gender'].isin(['Woman (cisgender)', 'Man (cisgender)'])].reset_index()
filtered_prompts['conversational']  = filtered_prompts['conversational'].apply(remove_newlines)

expanded_prompts
# Out:
#      index  message_id  conversation_id  role  \
# 0        0           1                1  user
# 1        1         730               32  user
# 2        2        1133               55  user
# 3        3        1135               55  user
# 4        4        1137               55  user
# ..     ...         ...              ...   ...
# 741    748        1646               82  user
# 742    749        1845               37  user
# 743    750        1847               37  user
# 744    751        1849                2  user
# 745    752        1851                2  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 741  def run_query(query, n_results):\n    query_em...
# 742  \n        nun möchte ich judgement balancing m...
# 743  \n    ich sehe keine veränderung im Plot. Was ...
# 744  \n    I am working on the problem of reconstru...
# 745  \n        Focus on one step at the time. Write...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 741  this is my code. I want to: Get nodes and edge...
# 742  Now I want to bring judgement balancing into t...
# 743               I do not see any change in the plot.
# 744       I am working on the problem of reconstruc...
# 745  Focus on one step at the time. Write what is t...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 741  def run_query(query, n_results):\n    query_em...
# 742
# 743
# 744
# 745
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 741                                                       Man (cisgender)
# 742                                                     Woman (cisgender)
# 743                                                     Woman (cisgender)
# 744  Classic CV - Drone navigation\nIf you ever tho...    Man (cisgender)
# 745                                                       Man (cisgender)
#
#      user_id language
# 0          6       en
# 1          6       en
# 2          6       en
# 3          6       en
# 4          6       en
# ..       ...      ...
# 741       92       en
# 742       29       de
# 743       29       de
# 744        8       en
# 745        8       en
#
# [746 rows x 11 columns]

# %% [markdown]
# ## Data stats and subsampling of long conversations
# - subsampled 50 prompts from user 73, who had over 200

# %%
users_per_gender = expanded_prompts.groupby('gender')['user_id'].nunique().reset_index(name='num_users')
users_per_gender
# Out:
#               gender  num_users
# 0    Man (cisgender)         15
# 1  Woman (cisgender)         13

# %%
messages_per_user = expanded_prompts.groupby('user_id')['message_id'].nunique().reset_index(name='num_messages')
messages_per_user
# Out:
#     user_id  num_messages
# 0         6             9
# 1         8             2
# 2        11            11
# 3        15             3
# 4        16            25
# 5        25             4
# 6        28            22
# 7        29             2
# 8        31             5
# 9        34            66
# 10       46             5
# 11       47            51
# 12       48            16
# 13       55            36
# 14       56             6
# 15       60             7
# 16       63             2
# 17       65            10
# 18       73           229
# 19       77            20
# 20       79            61
# 21       81             5
# 22       83            15
# 23       88             5
# 24       89            31
# 25       90            12
# 26       91            81
# 27       92             5

# %%
messages_per_gender = expanded_prompts.groupby('gender')['message_id'].nunique().reset_index(name='num_messages')
messages_per_gender
# Out:
#               gender  num_messages
# 0    Man (cisgender)           282
# 1  Woman (cisgender)           254

# %%
other_users = expanded_prompts[expanded_prompts['user_id'] != 73]
messages_per_other_users = other_users.groupby('user_id')['message_id'].nunique().reset_index(name='num_messages')
print("Mean message count: ", messages_per_other_users['num_messages'].mean())
# Out:
# Mean message count:  19.14814814814815

# %%
def subsample(df, id):
    user_73 = df[df['user_id'] == id]
    other_users = df[df['user_id'] != id]

    user_73_sampled = user_73.sample(n=19, random_state=42)

    prompts = pd.concat([other_users, user_73_sampled], ignore_index=True)

    subsampled_messages_per_user = prompts.groupby('user_id')['message_id'].nunique().reset_index(name='num_messages')
    subsampled_with_gender = subsampled_messages_per_user.merge(
        prompts[['user_id', 'gender']].drop_duplicates(),
        on='user_id',
        how='left'
    )
    print(subsampled_with_gender.groupby(['gender']).sum())

    users_per_gender = prompts.groupby('gender')['user_id'].nunique().reset_index(name='num_users')
    print(users_per_gender)

    return prompts

expanded_prompts = subsample(expanded_prompts, 73)
filtered_prompts = subsample(filtered_prompts, 73)
# Out:
#                    user_id  num_messages
# gender
# Man (cisgender)        780           282
# Woman (cisgender)      706           254
#               gender  num_users
# 0    Man (cisgender)         15
# 1  Woman (cisgender)         13
#                    user_id  num_messages
# gender
# Man (cisgender)        652           189
# Woman (cisgender)      612           186
#               gender  num_users
# 0    Man (cisgender)         13
# 1  Woman (cisgender)         11

# %% [markdown]
# ## Create label mapping

# %%
import json
def create_label_mapping(df):
    labels = df['gender'].astype('category')
    df['label'] = labels.cat.codes
    label2id = dict(enumerate(labels.cat.categories))
    with open("finetune/label2id.json", "w") as f:
        json.dump(label2id, f)
    return df

expanded_prompts = create_label_mapping(expanded_prompts)
filtered_prompts = create_label_mapping(filtered_prompts)

# %%
expanded_prompts
# Out:
#      index  message_id  conversation_id  role  \
# 0        0           1                1  user
# 1        1         730               32  user
# 2        2        1133               55  user
# 3        3        1135               55  user
# 4        4        1137               55  user
# ..     ...         ...              ...   ...
# 531    501        1674               87  user
# 532    416        1290               65  user
# 533    425        1314               65  user
# 534    309         372               21  user
# 535    503        1678               87  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  these are the results. i to calculate a statis...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 531
# 532  def perform_optics_clustering(file_path, outpu...
# 533
# 534
# 535
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...  Woman (cisgender)
# 532                                                     Woman (cisgender)
# 533                                                     Woman (cisgender)
# 534                                                     Woman (cisgender)
# 535                                                     Woman (cisgender)
#
#      user_id language  label
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 531       73       en      1
# 532       73       en      1
# 533       73       en      1
# 534       73       en      1
# 535       73       en      1
#
# [536 rows x 12 columns]

# %%
filtered_prompts
# Out:
#      index  message_id  conversation_id  role  \
# 0        0           1                1  user
# 1        1         730               32  user
# 2        2        1133               55  user
# 3        3        1135               55  user
# 4        4        1137               55  user
# ..     ...         ...              ...   ...
# 370    241         374               21  user
# 371    256         444               21  user
# 372    271         500               21  user
# 373    387        1398               65  user
# 374    312         865               44  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 370              Pass `sample_weight` to AutoGluon.how
# 371                   i dont understand the label part
# 372  ok, but what kind of information can i use fro...
# 373  data/docx-2017-04/diufgzadsgf.x;1\n    data/do...
# 374  please generate script, that turns this:\n'int...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 370              Pass `sample_weight` to AutoGluon.how
# 371                   i dont understand the label part
# 372  ok, but what kind of information can i use fro...
# 373        this is how the output should be formatted:
# 374  please generate script, that turns this:   to ...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 370              Pass `sample_weight` to AutoGluon.how
# 371
# 372
# 373  import pandas as pd\n\ndef create_clustered_ou...
# 374  [\n    {\n        "query": "\"Wordlist Scannin...
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 370                                                     Woman (cisgender)
# 371                                                     Woman (cisgender)
# 372                                                     Woman (cisgender)
# 373  data/docx-2017-04/diufgzadsgf.x;1\n    data/do...  Woman (cisgender)
# 374  'intrusion detection'': About 249 results (0,1...  Woman (cisgender)
#
#      user_id language  label
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 370       73       en      1
# 371       73       en      1
# 372       73       en      1
# 373       73       en      1
# 374       73       en      1
#
# [375 rows x 12 columns]

# %% [markdown]
# ## Save to database

# %%
expanded_prompts.to_sql('expanded_roberta_prompts', conn, if_exists='replace', index=False)
#filtered_prompts.to_sql('filtered_roberta_prompts', conn, if_exists='replace', index=False)

conn.close()
