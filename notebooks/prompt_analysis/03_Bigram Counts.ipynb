# %% [markdown]
# # Bigram Counts
#
# - bigrams are counted per prompt and normalized by the number of possible bigrams per prompt (n_tokens - 1)
# aggregation method: Per-sample Normalization & Averaging
# - all prompts are combined per user
# - counts per combined prompt are normalized by the number of possible bigrams in that prompt
# - counts are fused per gender and normalized by the size of each group
#  - this avoids to have longer prompt dominate the results as they would in pooling/global normalization

# %%
import sqlite3
import pandas as pd
import os

from helpers.occurences import load_spacy_lanuage_model, count_bigrams

db_path = "../../giicg.db"
if not os.path.exists(db_path):
    raise FileNotFoundError(f"Database file does not exist: {db_path}")

conn = sqlite3.connect(db_path)
prompts = pd.read_sql("SELECT ep.*, u.age, u.work_exp_years FROM expanded_prompts ep JOIN users u ON ep.user_id = u.user_id", conn)

user_prompts = (
    prompts
    .fillna({'work_exp_years': 'None'})
    .groupby(['user_id', 'gender', 'age', 'work_exp_years'])['conversational']
    .apply(' '.join)
    .reset_index()    # Reset index to create a DataFrame
)
user_prompts
# Out:
#     user_id             gender    age work_exp_years  \
# 0         6    Man (cisgender)  19-25            3.0
# 1        11  Woman (cisgender)  26-30            1.0
# 2        15    Man (cisgender)  26-30            6.0
# 3        16  Woman (cisgender)  19-25           None
# 4        25    Man (cisgender)  26-30            6.0
# 5        28  Woman (cisgender)  31-35            5.0
# 6        30         Non-binary  26-30           None
# 7        31    Man (cisgender)  36-40           22.0
# 8        34    Man (cisgender)  51-60           20.0
# 9        46    Man (cisgender)  31-35           12.0
# 10       47    Man (cisgender)  31-35           55.0
# 11       48  Woman (cisgender)  19-25           None
# 12       55  Woman (cisgender)  26-30            2.0
# 13       56    Man (cisgender)  26-30            9.0
# 14       60  Woman (cisgender)  19-25           None
# 15       63  Woman (cisgender)  26-30            2.0
# 16       65  Woman (cisgender)  19-25           None
# 17       73  Woman (cisgender)  31-35           None
# 18       77    Man (cisgender)  26-30            1.0
# 19       79  Woman (cisgender)  19-25            0.0
# 20       81    Man (cisgender)  26-30            1.0
# 21       83    Man (cisgender)  19-25            3.0
# 22       84     Another gender  36-40            4.0
# 23       88    Man (cisgender)  19-25           None
# 24       89  Woman (cisgender)  26-30            6.0
# 25       90  Woman (cisgender)  26-30            2.0
# 26       91    Man (cisgender)  31-35            6.0
# 27       92    Man (cisgender)  36-40            3.0
#
#                                        conversational
# 0   parsing data from python iterator how it could...
# 1   Can you adapt the following code so that inste...
# 2   SET_ALL_TABLES action is currently not fetchin...
# 3   I want to use Dummy Hot encoding to replace th...
# 4   what is the best way to encode and compress a ...
# 5   I have a pandas dataframe like this:\n\nI want...
# 6   as a NLP and LLM researcher I am recently down...
# 7   How can I make use of an ObservableHQDatabaseC...
# 8   Blender and Python. I have a collection of hun...
# 9   how to run a Python future without blocking i....
# 10  can you create Photoshop Scripts? In which for...
# 11  hey can you write me a short python script for...
# 12  write me a script that updates this chart to i...
# 13  add a short 5-second pause before spinning it ...
# 14  how can I combine two grib files in jupyter no...
# 15  can you give me a new code snippet where I jus...
# 16  I work with Python and have to read an NMEA fi...
# 17  please write method to unzip file in python pl...
# 18  I have this function that is supposed to perfo...
# 19  If a value in t+1 is <0.6 put it to zero but t...
# 20  I have a programming project and need help: Th...
# 21  Implement d3-force much closer to the way it i...
# 22  I have a typescript program. A function shall ...
# 23  in my html i have an iframe that is dynamicall...
# 24  are there paper where these metrics were first...
# 25  is there a way to get the object key in here? ...
# 26  hey I am writing an application. Because I wan...
# 27  Please replace my retrieval pipeline here with...

# %%
from helpers.occurences import load_spacy_lanuage_model, count_bigrams
model = load_spacy_lanuage_model()

user_prompts['bigram_counts'] = user_prompts['conversational'].apply(lambda x: count_bigrams(x, spacy_model=model))
user_prompts['n_bigrams'] = user_prompts['conversational'].apply(lambda x: len(x.split())-1)
user_prompts['normalized_bigram_counts'] = user_prompts.apply(
    lambda row: {bigram: count / row['n_bigrams'] if row['n_bigrams'] > 0 else 0
                 for bigram, count in row['bigram_counts'].items()},
    axis=1
)
user_prompts['sorted_bigram_counts'] = user_prompts['normalized_bigram_counts'].apply(
    lambda x: dict(sorted(x.items(), key=lambda item: item[1], reverse=True))
)


user_prompts
# Out:
#     user_id             gender    age work_exp_years  \
# 0         6    Man (cisgender)  19-25            3.0
# 1        11  Woman (cisgender)  26-30            1.0
# 2        15    Man (cisgender)  26-30            6.0
# 3        16  Woman (cisgender)  19-25           None
# 4        25    Man (cisgender)  26-30            6.0
# 5        28  Woman (cisgender)  31-35            5.0
# 6        30         Non-binary  26-30           None
# 7        31    Man (cisgender)  36-40           22.0
# 8        34    Man (cisgender)  51-60           20.0
# 9        46    Man (cisgender)  31-35           12.0
# 10       47    Man (cisgender)  31-35           55.0
# 11       48  Woman (cisgender)  19-25           None
# 12       55  Woman (cisgender)  26-30            2.0
# 13       56    Man (cisgender)  26-30            9.0
# 14       60  Woman (cisgender)  19-25           None
# 15       63  Woman (cisgender)  26-30            2.0
# 16       65  Woman (cisgender)  19-25           None
# 17       73  Woman (cisgender)  31-35           None
# 18       77    Man (cisgender)  26-30            1.0
# 19       79  Woman (cisgender)  19-25            0.0
# 20       81    Man (cisgender)  26-30            1.0
# 21       83    Man (cisgender)  19-25            3.0
# 22       84     Another gender  36-40            4.0
# 23       88    Man (cisgender)  19-25           None
# 24       89  Woman (cisgender)  26-30            6.0
# 25       90  Woman (cisgender)  26-30            2.0
# 26       91    Man (cisgender)  31-35            6.0
# 27       92    Man (cisgender)  36-40            3.0
#
#                                        conversational  \
# 0   parsing data from python iterator how it could...
# 1   Can you adapt the following code so that inste...
# 2   SET_ALL_TABLES action is currently not fetchin...
# 3   I want to use Dummy Hot encoding to replace th...
# 4   what is the best way to encode and compress a ...
# 5   I have a pandas dataframe like this:\n\nI want...
# 6   as a NLP and LLM researcher I am recently down...
# 7   How can I make use of an ObservableHQDatabaseC...
# 8   Blender and Python. I have a collection of hun...
# 9   how to run a Python future without blocking i....
# 10  can you create Photoshop Scripts? In which for...
# 11  hey can you write me a short python script for...
# 12  write me a script that updates this chart to i...
# 13  add a short 5-second pause before spinning it ...
# 14  how can I combine two grib files in jupyter no...
# 15  can you give me a new code snippet where I jus...
# 16  I work with Python and have to read an NMEA fi...
# 17  please write method to unzip file in python pl...
# 18  I have this function that is supposed to perfo...
# 19  If a value in t+1 is <0.6 put it to zero but t...
# 20  I have a programming project and need help: Th...
# 21  Implement d3-force much closer to the way it i...
# 22  I have a typescript program. A function shall ...
# 23  in my html i have an iframe that is dynamicall...
# 24  are there paper where these metrics were first...
# 25  is there a way to get the object key in here? ...
# 26  hey I am writing an application. Because I wan...
# 27  Please replace my retrieval pipeline here with...
#
#                                         bigram_counts  n_bigrams  \
# 0   {('parsing', 'data'): 1, ('data', 'from'): 1, ...        195
# 1   {('can', 'you'): 8, ('you', 'adapt'): 3, ('ada...        192
# 2   {('set_all_tables', 'action'): 1, ('action', '...         35
# 3   {('i', 'want'): 6, ('want', 'to'): 5, ('to', '...        543
# 4   {('what', 'is'): 1, ('is', 'the'): 1, ('the', ...        107
# 5   {('i', 'have'): 5, ('have', 'a'): 3, ('a', 'pa...        561
# 6   {('as', 'a'): 1, ('a', 'nlp'): 1, ('nlp', 'and...         91
# 7   {('how', 'can'): 2, ('can', 'i'): 3, ('i', 'ma...         91
# 8   {('blender', 'and'): 1, ('and', 'python'): 1, ...       1308
# 9   {('how', 'to'): 3, ('to', 'run'): 1, ('run', '...         68
# 10  {('can', 'you'): 7, ('you', 'create'): 1, ('cr...        903
# 11  {('hey', 'can'): 1, ('can', 'you'): 6, ('you',...        196
# 12  {('write', 'me'): 1, ('me', 'a'): 1, ('a', 'sc...        792
# 13  {('add', 'a'): 1, ('a', 'short'): 1, ('short',...         91
# 14  {('how', 'can'): 3, ('can', 'i'): 3, ('i', 'co...         96
# 15  {('can', 'you'): 1, ('you', 'give'): 1, ('give...         28
# 16  {('i', 'work'): 1, ('work', 'with'): 1, ('with...         76
# 17  {('please', 'write'): 7, ('write', 'method'): ...       3243
# 18  {('i', 'have'): 5, ('have', 'this'): 3, ('this...        473
# 19  {('if', 'a'): 1, ('a', 'value'): 3, ('value', ...        751
# 20  {('i', 'have'): 3, ('have', 'a'): 2, ('a', 'pr...        134
# 21  {('implement', 'd3'): 1, ('d3', 'force'): 1, (...        221
# 22  {('i', 'have'): 2, ('have', 'a'): 2, ('a', 'ty...        251
# 23  {('in', 'my'): 1, ('my', 'html'): 1, ('html', ...         65
# 24  {('are', 'there'): 1, ('there', 'paper'): 1, (...        448
# 25  {('is', 'there'): 1, ('there', 'a'): 1, ('a', ...        212
# 26  {('hey', 'i'): 1, ('i', 'am'): 6, ('am', 'writ...       1369
# 27  {('please', 'replace'): 1, ('replace', 'my'): ...        159
#
#                              normalized_bigram_counts  \
# 0   {('parsing', 'data'): 0.005128205128205128, ('...
# 1   {('can', 'you'): 0.041666666666666664, ('you',...
# 2   {('set_all_tables', 'action'): 0.0285714285714...
# 3   {('i', 'want'): 0.011049723756906077, ('want',...
# 4   {('what', 'is'): 0.009345794392523364, ('is', ...
# 5   {('i', 'have'): 0.008912655971479501, ('have',...
# 6   {('as', 'a'): 0.01098901098901099, ('a', 'nlp'...
# 7   {('how', 'can'): 0.02197802197802198, ('can', ...
# 8   {('blender', 'and'): 0.0007645259938837921, ('...
# 9   {('how', 'to'): 0.04411764705882353, ('to', 'r...
# 10  {('can', 'you'): 0.007751937984496124, ('you',...
# 11  {('hey', 'can'): 0.00510204081632653, ('can', ...
# 12  {('write', 'me'): 0.0012626262626262627, ('me'...
# 13  {('add', 'a'): 0.01098901098901099, ('a', 'sho...
# 14  {('how', 'can'): 0.03125, ('can', 'i'): 0.0312...
# 15  {('can', 'you'): 0.03571428571428571, ('you', ...
# 16  {('i', 'work'): 0.013157894736842105, ('work',...
# 17  {('please', 'write'): 0.002158495220474869, ('...
# 18  {('i', 'have'): 0.010570824524312896, ('have',...
# 19  {('if', 'a'): 0.0013315579227696406, ('a', 'va...
# 20  {('i', 'have'): 0.022388059701492536, ('have',...
# 21  {('implement', 'd3'): 0.004524886877828055, ('...
# 22  {('i', 'have'): 0.00796812749003984, ('have', ...
# 23  {('in', 'my'): 0.015384615384615385, ('my', 'h...
# 24  {('are', 'there'): 0.002232142857142857, ('the...
# 25  {('is', 'there'): 0.0047169811320754715, ('the...
# 26  {('hey', 'i'): 0.0007304601899196494, ('i', 'a...
# 27  {('please', 'replace'): 0.006289308176100629, ...
#
#                                  sorted_bigram_counts
# 0   {('need', 'to'): 0.020512820512820513, ('like'...
# 1   {('can', 'you'): 0.041666666666666664, ('you',...
# 2   {('set_all_tables', 'action'): 0.0285714285714...
# 3   {('can', 'i'): 0.01289134438305709, ('i', 'wan...
# 4   {('a', 'type'): 0.018691588785046728, ('i', 'w...
# 5   {('want', 'to'): 0.0213903743315508, ('i', 'wa...
# 6   {('rename', 'all'): 0.02197802197802198, ('all...
# 7   {('can', 'i'): 0.03296703296703297, ('how', 'c...
# 8   {('of', 'the'): 0.00764525993883792, ('the', '...
# 9   {('how', 'to'): 0.04411764705882353, ('a', 'co...
# 10  {('to', 'the'): 0.012181616832779624, ('can', ...
# 11  {('can', 'you'): 0.030612244897959183, ('the',...
# 12  {('i', 'want'): 0.015151515151515152, ('want',...
# 13  {('at', 'the'): 0.02197802197802198, ('the', '...
# 14  {('how', 'can'): 0.03125, ('can', 'i'): 0.0312...
# 15  {('can', 'you'): 0.03571428571428571, ('you', ...
# 16  {('please', 'write'): 0.02631578947368421, ('t...
# 17  {('want', 'to'): 0.013259327782917052, ('i', '...
# 18  {('i', 'have'): 0.010570824524312896, ('this',...
# 19  {('of', 'the'): 0.010652463382157125, ('does',...
# 20  {('i', 'have'): 0.022388059701492536, ('of', '...
# 21  {('built', 'in'): 0.01809954751131222, ('of', ...
# 22  {('values', 'in'): 0.01195219123505976, ('the'...
# 23  {('in', 'my'): 0.015384615384615385, ('my', 'h...
# 24  {('how', 'to'): 0.008928571428571428, ('table'...
# 25  {('can', 'you'): 0.018867924528301886, ('the',...
# 26  {('to', 'the'): 0.008765522279035792, ('of', '...
# 27  {('i', 'want'): 0.025157232704402517, ('want',...

# %%
from helpers.occurences import merge_counts

genders = user_prompts[['gender']].drop_duplicates().reset_index(drop=True)
gender_bigram_dict = {}

for gender, group in user_prompts.groupby("gender"):
    counts_list = group["normalized_bigram_counts"].tolist()
    total_counts = merge_counts(counts_list)
    num_prompts = group.shape[0]
    print(gender, num_prompts)
    normalized_counts = {bigram: count / num_prompts for bigram, count in total_counts.items()}
    sorted_bigram_counts = dict(sorted(normalized_counts.items(), key=lambda item: item[1], reverse=True))
    gender_bigram_dict[gender] = sorted_bigram_counts

genders['normalized_bigram_counts'] = genders['gender'].map(gender_bigram_dict)
genders
# Out:
# Another gender 1
# Man (cisgender) 14
# Non-binary 1
# Woman (cisgender) 12
#               gender                           normalized_bigram_counts
# 0    Man (cisgender)  {('of', 'the'): 0.005577501049396659, ('in', '...
# 1  Woman (cisgender)  {('can', 'you'): 0.0126163459928249, ('i', 'wa...
# 2         Non-binary  {('rename', 'all'): 0.02197802197802198, ('all...
# 3     Another gender  {('values', 'in'): 0.01195219123505976, ('the'...

# %%
age_classes = user_prompts[['age']].drop_duplicates().reset_index(drop=True)
gender_bigram_dict = {}

for age_class, group in user_prompts.groupby("age"):
    counts_list = group["normalized_bigram_counts"].tolist()
    total_counts = merge_counts(counts_list)
    num_prompts = group.shape[0]
    print(age_class, num_prompts)
    normalized_counts = {bigram: count / num_prompts for bigram, count in total_counts.items()}
    sorted_bigram_counts = dict(sorted(normalized_counts.items(), key=lambda item: item[1], reverse=True))
    gender_bigram_dict[age_class] = sorted_bigram_counts

counts = user_prompts.groupby(['age', 'gender']).size().unstack(fill_value=0)
print(counts)

age_classes['normalized_bigram_counts'] = age_classes['age'].map(gender_bigram_dict)
age_classes
# Out:
# 19-25 8
# 26-30 11
# 31-35 5
# 36-40 3
# 51-60 1
# gender  Another gender  Man (cisgender)  Non-binary  Woman (cisgender)
# age
# 19-25                0                3           0                  5
# 26-30                0                5           1                  5
# 31-35                0                3           0                  2
# 36-40                1                2           0                  0
# 51-60                0                1           0                  0
#      age                           normalized_bigram_counts
# 0  19-25  {('how', 'can'): 0.007146784554767512, ('can',...
# 1  26-30  {('can', 'you'): 0.010127451372739378, ('of', ...
# 2  31-35  {('how', 'to'): 0.009929319095521267, ('want',...
# 3  36-40  {('can', 'i'): 0.012317032237350964, ('i', 'wa...
# 4  51-60  {('of', 'the'): 0.00764525993883792, ('the', '...

# %%
bins = [-float('inf'), 1, 3, 5, 10, float('inf')]
labels = ['<=1', '1-3', '3-5', '5-10', '>10']
user_prompts['work_exp_years'] = pd.to_numeric(user_prompts['work_exp_years'], errors='coerce')
user_prompts['work_exp_group'] = (
    pd.cut(user_prompts['work_exp_years'], bins=bins, labels=labels, right=True)
    .astype(str)
    .replace("nan", "")
)

exp_classes = user_prompts[['work_exp_group']].drop_duplicates().reset_index(drop=True)

gender_bigram_dict = {}

for exp_class, group in user_prompts.groupby("work_exp_group"):
    counts_list = group["normalized_bigram_counts"].tolist()
    total_counts = merge_counts(counts_list)
    num_prompts = group.shape[0]
    print(exp_class, num_prompts)
    normalized_counts = {bigram: count / num_prompts for bigram, count in total_counts.items()}
    sorted_bigram_counts = dict(sorted(normalized_counts.items(), key=lambda item: item[1], reverse=True))
    gender_bigram_dict[exp_class] = sorted_bigram_counts

counts = user_prompts.groupby(['work_exp_group', 'gender']).size().unstack(fill_value=0)
print(counts)

exp_classes['normalized_bigram_counts'] = exp_classes['work_exp_group'].map(gender_bigram_dict)
exp_classes
# Out:
#  7
# 1-3 6
# 3-5 2
# 5-10 5
# <=1 4
# >10 4
# gender          Another gender  Man (cisgender)  Non-binary  Woman (cisgender)
# work_exp_group
#                              0                1           1                  5
# 1-3                          0                3           0                  3
# 3-5                          1                0           0                  1
# 5-10                         0                4           0                  1
# <=1                          0                2           0                  2
# >10                          0                4           0                  0
#   work_exp_group                           normalized_bigram_counts
# 0            1-3  {('of', 'the'): 0.011780353900220716, ('can', ...
# 1            <=1  {('can', 'you'): 0.014195278974991295, ('of', ...
# 2           5-10  {('in', 'the'): 0.009498946001535039, ('need',...
# 3                 {('how', 'can'): 0.008065633062215161, ('i', '...
# 4            3-5  {('want', 'to'): 0.01467925091079532, ('i', 'w...
# 5            >10  {('how', 'to'): 0.011029411764705883, ('can', ...
