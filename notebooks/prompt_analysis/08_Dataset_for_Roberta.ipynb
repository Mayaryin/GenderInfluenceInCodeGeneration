# %% [markdown]
# # Preparing the data for Roberta Finetuning
# - exporting two datasets:
#     - fully corrected
#     - raw prompts wihtout the ones in german and italian
# - both contain original punctuation

# %%
import sqlite3
import pandas as pd

conn  = sqlite3.connect('../../giicg.db')
expanded_prompts = pd.read_sql("Select * from expanded_prompts", conn).drop_duplicates(subset=['conversational'])
filtered_prompts = pd.read_sql(
    """
    SELECT
        fp.*,
        ep.language
    FROM
        filtered_prompts fp
    JOIN
        expanded_prompts ep
    ON
        fp.message_id = ep.message_id
    """,
    conn
).drop_duplicates(subset=['conversational'])

# %% [markdown]
# ## Filter and Clean

# %%
from helpers.normalization import remove_newlines

expanded_prompts = expanded_prompts[expanded_prompts['gender'].isin(['Woman (cisgender)', 'Man (cisgender)'])].reset_index()
expanded_prompts['conversational']  = expanded_prompts['conversational'].apply(remove_newlines)

filtered_prompts = filtered_prompts[filtered_prompts['language'] == 'en'].reset_index(drop=True)
filtered_prompts = filtered_prompts[filtered_prompts['gender'].isin(['Woman (cisgender)', 'Man (cisgender)'])].reset_index()
filtered_prompts['conversational']  = filtered_prompts['conversational'].apply(remove_newlines)

# %% [markdown]
# ## Data stats and subsampling of long conversations
# - subsampled 50 prompts from user 73, who had over 200

# %%
users_per_gender = all_prompts.groupby('gender')['user_id'].nunique().reset_index(name='num_users')
users_per_gender
# Out:
#               gender  num_users
# 0    Man (cisgender)         15
# 1  Woman (cisgender)         12

# %%
messages_per_user = all_prompts.groupby('user_id')['message_id'].nunique().reset_index(name='num_messages')
messages_per_user
# Out:
#     user_id  num_messages
# 0         6             9
# 1         8             2
# 2        11            11
# 3        15             3
# 4        16            25
# 5        25             4
# 6        28            22
# 7        31             5
# 8        34            66
# 9        46             5
# 10       47            51
# 11       48            16
# 12       55            36
# 13       56             6
# 14       60             7
# 15       63             2
# 16       65            10
# 17       73           229
# 18       77            20
# 19       79            61
# 20       81             5
# 21       83            15
# 22       88             5
# 23       89            31
# 24       90            14
# 25       91            81
# 26       92             5

# %%
def subsample(df, id):
    user_73 = df[df['user_id'] == id]
    other_users = df[df['user_id'] != id]

    user_73_sampled = user_73.sample(n=50, random_state=42)

    prompts = pd.concat([other_users, user_73_sampled], ignore_index=True)

    subsampled_messages_per_user = prompts.groupby('user_id')['message_id'].nunique().reset_index(name='num_messages')
    subsampled_with_gender = subsampled_messages_per_user.merge(
        prompts[['user_id', 'gender']].drop_duplicates(),
        on='user_id',
        how='left'
    )
    print(subsampled_with_gender.groupby(['gender']).sum())

    users_per_gender = prompts.groupby('gender')['user_id'].nunique().reset_index(name='num_users')
    print(users_per_gender)

    return prompts

expanded_prompts = subsample(expanded_prompts, 73)
filtered_prompts = subsample(filtered_prompts, 73)
# Out:
#                    user_id  num_messages
# gender
# Man (cisgender)        780           282
# Woman (cisgender)      677           285
#               gender  num_users
# 0    Man (cisgender)         15
# 1  Woman (cisgender)         12
#                    user_id  num_messages
# gender
# Man (cisgender)        652           189
# Woman (cisgender)      612           217
#               gender  num_users
# 0    Man (cisgender)         13
# 1  Woman (cisgender)         11

# %% [markdown]
# ## Create label mapping

# %%
import json
def create_label_mapping(df):
    labels = df['gender'].astype('category')
    df['label'] = labels.cat.codes
    label2id = dict(enumerate(labels.cat.categories))
    with open("finetune/label2id.json", "w") as f:
        json.dump(label2id, f)
    return df

expanded_prompts = create_label_mapping(expanded_prompts)
filtered_prompts = create_label_mapping(filtered_prompts)

# %%
expanded_prompts
# Out:
#      index  message_id  conversation_id  role  \
# 0        0           1                1  user
# 1        1         730               32  user
# 2        2        1133               55  user
# 3        3        1135               55  user
# 4        4        1137               55  user
# ..     ...         ...              ...   ...
# 562    391        1234               65  user
# 563    429        1322               65  user
# 564    334         484               21  user
# 565    444        1364               65  user
# 566    348         516               21  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 562             can we add peid for when pefile fails?
# 563  param_grid = {\n    'min_samples': [5, 10, 20]...
# 564  i think i onlz want to think about the imbalan...
# 565  from sklearn.cluster import OPTICS\nfrom sklea...
# 566  ah it did work.\nnow i want to run:\npredictor...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 562             can we add peid for when pefile fails?
# 563                                 provide more steps
# 564  i think i only want to think about the imbalan...
# 565  this worked. but i do not have visualizations ...
# 566                 ah it did work. now i want to run:
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 562
# 563  param_grid = {\n    'min_samples': [5, 10, 20]...
# 564
# 565  from sklearn.cluster import OPTICS\nfrom sklea...
# 566  predictor.fit(\n    train_data=train_data,  # ...
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 562                                                     Woman (cisgender)
# 563                                                     Woman (cisgender)
# 564                                                     Woman (cisgender)
# 565                                                     Woman (cisgender)
# 566  over each class 0 to 10 and create a model for...  Woman (cisgender)
#
#      user_id language  label
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 562       73       en      1
# 563       73       en      1
# 564       73       en      1
# 565       73       en      1
# 566       73       en      1
#
# [567 rows x 12 columns]

# %%
filtered_prompts
# Out:
#      index  message_id  conversation_id  role  \
# 0        0           1                1  user
# 1        1         730               32  user
# 2        2        1133               55  user
# 3        3        1135               55  user
# 4        4        1137               55  user
# ..     ...         ...              ...   ...
# 401    374        1364               65  user
# 402    278         514               21  user
# 403    266         486               21  user
# 404    335        1268               65  user
# 405    338        1274               65  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 401  from sklearn.cluster import OPTICS\nfrom sklea...
# 402                            this doesnt do anything
# 403  3\. **Class Weighting**this looks promising.\n...
# 404  import pandas as pd\nfrom sklearn.manifold imp...
# 405            can't i reuse the method we just wrote?
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 401  this worked. but i dont have visualisaitons an...
# 402                            this doesnt do anything
# 403  this looks promising. so my unmanipluated clas...
# 404  please use different color for every label no ...
# 405            can't i reuse the method we just wrote?
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 401  from sklearn.cluster import OPTICS\nfrom sklea...
# 402
# 403
# 404  import pandas as pd\nfrom sklearn.manifold imp...
# 405
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 401                                                     Woman (cisgender)
# 402                            this doesnt do anything  Woman (cisgender)
# 403                             3. **Class Weighting**  Woman (cisgender)
# 404                                                     Woman (cisgender)
# 405                                                     Woman (cisgender)
#
#      user_id language  label
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 401       73       en      1
# 402       73       en      1
# 403       73       en      1
# 404       73       en      1
# 405       73       en      1
#
# [406 rows x 12 columns]

# %% [markdown]
# ## Save to database

# %%
expanded_prompts.to_sql('expanded_roberta_prompts', conn, if_exists='replace', index=False)
filtered_prompts.to_sql('filtered_roberta_prompts', conn, if_exists='replace', index=False)

conn.close()
