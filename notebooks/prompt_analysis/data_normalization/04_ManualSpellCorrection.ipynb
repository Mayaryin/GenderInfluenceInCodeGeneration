# %% [markdown]
# # Manual spell correction of the prompts
#
# This notebook documents manual spell correction steps applied to the prompts table, to be able to replicate manual cleaning steps and to trace back what was changed. Each rule is documented with its purpose and implementation,
# The original prompts table remains unchanged - all output goes to `manually_corrected_prompts`.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../../../giicg.db")
prompts= pd.read_sql("SELECT * FROM expanded_roberta_prompts", conn)
prompts
# Out:
#      level_0  index  message_id  conversation_id  role  \
# 0          0      0           1                1  user
# 1          1      1         730               32  user
# 2          2      2        1133               55  user
# 3          3      3        1135               55  user
# 4          4      4        1137               55  user
# ..       ...    ...         ...              ...   ...
# 531      531    501        1674               87  user
# 532      532    416        1290               65  user
# 533      533    425        1314               65  user
# 534      534    309         372               21  user
# 535      535    503        1678               87  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  these are the results. i to calculate a statis...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 531
# 532  def perform_optics_clustering(file_path, outpu...
# 533
# 534
# 535
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...  Woman (cisgender)
# 532                                                     Woman (cisgender)
# 533                                                     Woman (cisgender)
# 534                                                     Woman (cisgender)
# 535                                                     Woman (cisgender)
#
#      user_id language  label  \
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 531       73       en      1
# 532       73       en      1
# 533       73       en      1
# 534       73       en      1
# 535       73       en      1
#
#                                          masked_prompt  \
# 0    parsing data from [TERM], how it could be hand...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating [TERM] on ...
# 3                                       what is [TERM]
# 4    Transform given code to process large [TERM] file
# ..                                                 ...
# 531  [INFO]\n[INFO]\n[TERM]:\n  [TERM]: [OTHER]\n  ...
# 532  how are we currently processing non numerical ...
# 533                                 what is the [TERM]
# 534  my features are saved in [TERM] and the file n...
# 535  great now please move more stuff from main to ...
#
#                                      masked_translated
# 0    parsing data from [TERM], how it could be hand...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating [TERM] on ...
# 3                                       what is [TERM]
# 4    Transform given code to process large [TERM] file
# ..                                                 ...
# 531  [INFO]\n[INFO]\n[TERM]:\n  [TERM]: [OTHER]\n  ...
# 532  how are we currently processing non numerical ...
# 533                                 what is the [TERM]
# 534  my features are saved in [TERM] and the file n...
# 535  great now please move more stuff from main to ...
#
# [536 rows x 15 columns]

# %%
import re


# Correct Spelling

def fix_spelling_errors(df):
    """Fix common spelling errors in conversational content"""
    corrections = {
        'orthogogal': 'orthogonal',
        'Anothers' : 'Another',
        'follwoing' : 'following',
        'insted' : 'instead',
        'thats' : 'that\'s',
        'addtion' : 'addition',
        'develope' : 'develop',
        'familys' : 'families',
        'responsable' : 'responsible',
        'optimate' : 'optimize',
        'esier' : 'easier',
        'sentencs': 'sentences',
        'preveent' : 'prevent',
        'indexs': 'indices',
        'hundrets': 'hundreds',
        'orthotogonal' : 'orthogonal',
        'palatte' : 'plaette',
        'favoriting' : 'favoring',
        'orignal' : 'original',
        'resemblens' : 'resemblance',
        'appoinment' : 'appointment',
        'Canvaslet\'s' : 'let\'s',
        'ealier' : 'earlier',
        'Rectlange' : 'Rectangle',
        'gesorächslauf' : 'chat history',
        'evry': 'every',
        'inlcude': 'include',
        'wrtie' : 'write',
        'tring' : 'trying',
        'im' : 'i\'m',
        'exaple' : 'example',
        'modalitieees': 'modalities',
        'doenst' : 'doesn\'t',
        'actualy': 'actually',
        'paremeter': 'parameter',
        'experiement': 'experiment',
        'concatination' : 'concatenation',
        'impliment' : 'implement',
        'impilmentation' : 'implementation',
        'nessacary' : 'necessary',
        'caclulated' : 'calculated',
        'matrixes' : 'matrices',
        'writie' : 'write',
        'follws' : 'follows',
        'inlcuded' : 'included',
        'origional' : 'original',
        'thta' : 'that',
        'heres' : 'here\'s',
        'laike' : 'like',
        'wehre' : 'where',
        'reuslts':'results',
        'intersetd' : 'interested',
        'concatition' : 'concatenation',
        'paramters' : 'parameters',
        'implyin' : 'implying',
        'guassion' : 'gaussian',
        'thigns' : 'things',
        'dockerfule' : 'dockerfile',
        'snipped'  : 'snippet',
        'viseos' : 'videos',
        'phne' : 'without',
        'Asked ChatGPTi' : 'i',
        'Asked ChatGPTplease' : 'please',
        'deday' : 'decay',
        'seperate' : 'separate',
        'apporach' : 'approach',
        'indiviually' : 'individually',
        'allegeded' : 'alleged',
        'Asked ChatGPTwhy' : 'why',
        'testset' : 'test set',
        'classificaiton' : 'classification',
        'optimice' : 'optimize',
        'adaptbefore' : 'adapt before',
        'onlz' : 'only',
        'sepearte' : 'separate',
        'informaiton' : 'information',
        'validaiton' : 'validation',
        'overfitiing' : 'overfitting',
        'eahc' : 'each',
        'directorys' : 'directories',
        'direcrtorys' : 'directories',
        'manipultaet' : 'manipulated',
        'aere' : 'are',
        'withoud' : 'without',
        'thorugh' : 'thorugh',
        'please provide example hot to use' : 'please provide example how to use',
        'rewertie' : 'rewrite',
        'Uploaded an imagei' : 'i',
        'inforamtion' : 'information',
        'visualiysing' : 'visualizing',
        'achive' : 'achieve',
        'sohuellete' : 'silhouette',
        'autimatically' : 'automatically',
        'entrys' : 'entries',
        'visualisaitons' : 'visualizations',
        'seachr' : 'search',
        'searhc' : 'search',
        'shoulndt' : 'shouldn\'t',
        'llookng' : 'looking',
        'clutering' : 'clustering',
        'restuks' : 'results',
        'mehtod' : 'method',
        'delimimetr' : 'delimiter',
        'strucuture' : 'structure',
        'neccessary' : 'necessary',
        'extractzion' : 'extraction',
        'suddently' : 'suddenly',
        'miminal' : 'minimal',
        'isnt' : 'isn\'t',
        'anomalious' : 'anomalous',
        'staistical' : 'statistical',
        'vlaues' : 'values',
        'calsses' : 'classes',
        'ommitted' : 'omitted',
        'approcheas' : 'approaches',
        'inthe' : 'in the',
        'sceintificly' : 'scientifically',
        'Uploaded to filethis' : 'this',
        'soonn' : 'soon',
        'dissappear' : 'disappear',
        'tryping' : 'trying',
        'undefinded' : 'undefined',
        'lenght' : 'length',
        'overritten' : 'overwritten',
        'exisiting' : 'existing',
        'caluclate' : 'calculate',
        'optimise' : 'optimize',
        'Fehlermeldungen' : 'error messages',
        'HEader' : 'Header',
        'nich tunterstrichen' : 'no underscore',
        'carussel': 'carousel',
        'adress' : 'address',
        'blancs' : 'blanks',
        'doesnt' : 'doesn\'t',
        'didnt' : 'didn\'t',
        'lets' : 'let\'s',
        'cant' : 'can\'t',
        'formated' : 'formatted',
        'unmanipluated': 'unmanipulated',
        'additonal': 'additional',
        'pls': 'please',
        'plz': 'please'

    }

    total_fixes = 0
    for incorrect, correct in corrections.items():
        # Create regex pattern for exact word match (case-insensitive)
        pattern = r'\b' + re.escape(incorrect) + r'\b'

        # Check if pattern exists in any row
        mask = df['masked_translated'].str.contains(pattern, case=False, na=False, regex=True)

        if mask.any():
            # Replace using regex with word boundaries
            df['masked_translated'] = df['masked_translated'].str.replace(
                pattern, correct, case=False, regex=True
            )
            total_fixes += mask.sum()


    print(f"Fixed spelling in {total_fixes} rows")
    return df

# %%
def apply_all_rules(df):
    """Apply all cleaning rules in sequence"""
    print(f"Starting with {len(df)} rows")
    print("-" * 40)

    df = fix_spelling_errors(df)

    print("-" * 40)
    print(f"Final: {len(df)} rows")
    return df

# Apply rules
corrected_prompts = apply_all_rules(prompts.copy())
corrected_prompts
# Out:
# Starting with 536 rows
# ----------------------------------------
# Fixed spelling in 101 rows
# ----------------------------------------
# Final: 536 rows
#      level_0  index  message_id  conversation_id  role  \
# 0          0      0           1                1  user
# 1          1      1         730               32  user
# 2          2      2        1133               55  user
# 3          3      3        1135               55  user
# 4          4      4        1137               55  user
# ..       ...    ...         ...              ...   ...
# 531      531    501        1674               87  user
# 532      532    416        1290               65  user
# 533      533    425        1314               65  user
# 534      534    309         372               21  user
# 535      535    503        1678               87  user
#
#                                           message_text  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                         conversational  \
# 0    parsing data from python iterator, how it coul...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating RAG on ema...
# 3                                        what is FAISS
# 4     Transform given code to process large .mbox file
# ..                                                 ...
# 531  these are the results. i to calculate a statis...
# 532  how are we currently processing non numerical ...
# 533                     what is the reachability score
# 534  my features are saved in "train_features.npy" ...
# 535  great now please move more stuff from main to ...
#
#                                                   code  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 531
# 532  def perform_optics_clustering(file_path, outpu...
# 533
# 534
# 535
#
#                                                  other             gender  \
# 0                                                         Man (cisgender)
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 2                                                         Man (cisgender)
# 3                                                         Man (cisgender)
# 4     Transform given code to process large .mbox file    Man (cisgender)
# ..                                                 ...                ...
# 531  Accuracy: 1.0\n  Count: 2\nMetrics for neptune...  Woman (cisgender)
# 532                                                     Woman (cisgender)
# 533                                                     Woman (cisgender)
# 534                                                     Woman (cisgender)
# 535                                                     Woman (cisgender)
#
#      user_id language  label  \
# 0          6       en      0
# 1          6       en      0
# 2          6       en      0
# 3          6       en      0
# 4          6       en      0
# ..       ...      ...    ...
# 531       73       en      1
# 532       73       en      1
# 533       73       en      1
# 534       73       en      1
# 535       73       en      1
#
#                                          masked_prompt  \
# 0    parsing data from [TERM], how it could be hand...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating [TERM] on ...
# 3                                       what is [TERM]
# 4    Transform given code to process large [TERM] file
# ..                                                 ...
# 531  [INFO]\n[INFO]\n[TERM]:\n  [TERM]: [OTHER]\n  ...
# 532  how are we currently processing non numerical ...
# 533                                 what is the [TERM]
# 534  my features are saved in [TERM] and the file n...
# 535  great now please move more stuff from main to ...
#
#                                      masked_translated
# 0    parsing data from [TERM], how it could be hand...
# 1    Write python function to do operations with in...
# 2    Write shortest tutorial on creating [TERM] on ...
# 3                                       what is [TERM]
# 4    Transform given code to process large [TERM] file
# ..                                                 ...
# 531  [INFO]\n[INFO]\n[TERM]:\n  [TERM]: [OTHER]\n  ...
# 532  how are we currently processing non numerical ...
# 533                                 what is the [TERM]
# 534  my features are saved in [TERM] and the file n...
# 535  great now please move more stuff from main to ...
#
# [536 rows x 15 columns]

# %%
differences = prompts.compare(corrected_prompts)
# Get rows that have any differences
altered_rows_mask = ~prompts.eq(corrected_prompts).all(axis=1)
altered_df = corrected_prompts[altered_rows_mask]

altered_df
# Out:
#      message_id  conversation_id  role  \
# 1           730               32  user
# 14         1151               56  user
# 23            5                6  user
# 26           11                6  user
# 27           13                6  user
# ..          ...              ...   ...
# 726        1089               53  user
# 727        1091               53  user
# 729        1095               53  user
# 730        1097               53  user
# 733        1103               53  user
#
#                                           message_text  \
# 1    Write python function to do operations with in...
# 14   I tried to do the same to the monthly views bu...
# 23   I want to use Dummy Hot encoding to replace th...
# 26   Ok back to the Embarked column. I have realise...
# 27   No thats not what I mean. I mean there is a dr...
# ..                                                 ...
# 726  the approach is right. but i left the general ...
# 727  how do i declare attributes to a inside of hea...
# 729  for the header links, i'd like to introduce an...
# 730  ok nice. can i let the color switch already on...
# 733  ill send you some links, please turn all links...
#
#                                         conversational code  \
# 1    Write python function to do operations with in...
# 14   I tried to do the same to the monthly views bu...
# 23   I want to use Dummy Hot encoding to replace th...
# 26   Ok back to the Embarked column. I have realise...
# 27   No that's not what I mean. I mean there is a d...
# ..                                                 ...  ...
# 726  the approach is right. but i left the general ...
# 727  how do i declare attributes to a inside of Hea...
# 729  for the Header links, i'd like to introduce an...
# 730  ok nice. can i let the color switch already on...
# 733  ill send you some links, please turn all links...
#
#                                                  other             gender  \
# 1    report_dt\tsource\tmetric_name\tmetric_num\tme...    Man (cisgender)
# 14                                                      Woman (cisgender)
# 23                                                      Woman (cisgender)
# 26                                                      Woman (cisgender)
# 27                                                      Woman (cisgender)
# ..                                                 ...                ...
# 726                                                       Man (cisgender)
# 727                                                       Man (cisgender)
# 729                                                       Man (cisgender)
# 730                                                       Man (cisgender)
# 733                                                       Man (cisgender)
#
#      user_id language
# 1          6       en
# 14        11       en
# 23        16       en
# 26        16       en
# 27        16       en
# ..       ...      ...
# 726       91       en
# 727       91       en
# 729       91       en
# 730       91       en
# 733       91       en
#
# [136 rows x 10 columns]

# %%
corrected_prompts.to_sql('expanded_roberta_prompts', conn, if_exists='replace', index=False)
# Out:
# 536
