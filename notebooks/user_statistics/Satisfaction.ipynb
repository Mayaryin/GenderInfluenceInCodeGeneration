# %% [markdown]
# # Satisfaction

# %%
import pandas as pd
import sqlite3

from helpers.statistical_tests import run_t_test_on_gender

conn = sqlite3.connect("../../giicg.db")
users = pd.read_sql("Select c.*, u.gender from conversations c JOIN users u on c.user_id == u.user_id", conn)
conn.close()
users = users[(users['gender'].isin(['Man (cisgender)', 'Woman (cisgender)']))]

# %%
satisfaction_map = {
    'very dissatisfied': 1,
    'mostly dissatisfied': 2,
    'neutral': 3,
    'somewhat satisfied': 4,
    'very satisfied': 5
}

complexity_map = {
    'very simple': 1,
    'relatively simple': 2,
    'neither complex nor simple': 3,
    'relatively complex': 4,
    'very complex': 5
}

# Create a new column with coded values
users['satisfaction_code'] = users['satisfaction'].map(satisfaction_map)
users['complexity_code'] = users['rated_complexity'].map(complexity_map)

users
# Out:
#     conversation_id  user_id        mode  \
# 0                 1        6  Share link
# 1                 2        8   JSON/Text
# 2                 3       11  Share link
# 3                 4       14  Share link
# 4                 5       15   JSON/Text
# ..              ...      ...         ...
# 85               86       60  Share link
# 86               87       73  Share link
# 87               88       77  Share link
# 88               89       79  Share link
# 89               90       90  Share link
#
#                                                  text  \
# 0                                                None
# 1   I am working on the problem of reconstruction ...
# 2                                                None
# 3                                                None
# 4   SET_ALL_TABLES action is currently not fetchin...
# ..                                                ...
# 85                                               None
# 86                                               None
# 87                                               None
# 88                                               None
# 89                                               None
#
#                                            share_link           llm_version  \
# 0   https://chatgpt.com/share/682b3298-bd58-8000-b...                  None
# 1                                                None  ChatGPT-4o-mini-high
# 2   https://chatgpt.com/share/682b387d-16ec-8010-8...                  None
# 3   https://chatgpt.com/share/682b48e3-94c0-8005-8...                  None
# 4                                                None     Claude 3.7 Sonnet
# ..                                                ...                   ...
# 85  https://chatgpt.com/share/68358d62-9b20-800d-a...            ChatGPT-4o
# 86  https://chatgpt.com/share/68385b69-0548-800c-9...            ChatGPT-4o
# 87  https://chatgpt.com/share/683edda1-2be8-800d-9...             ChatGPT-4
# 88  https://chatgpt.com/share/683eecd0-d638-800d-8...                gpt-40
# 89  https://chatgpt.com/share/68767ddd-ef98-8001-9...               ChatGPT
#
#           satisfaction explain_satisfaction            rated_complexity  \
# 0              neutral                 None  neither complex nor simple
# 1   somewhat satisfied                 None          relatively complex
# 2       very satisfied                 None                 very simple
# 3   somewhat satisfied                 None  neither complex nor simple
# 4   somewhat satisfied                 None          relatively complex
# ..                 ...                  ...                         ...
# 85      very satisfied                 None                 very simple
# 86  somewhat satisfied                 None  neither complex nor simple
# 87  somewhat satisfied                 None                 very simple
# 88  somewhat satisfied                 None          relatively complex
# 89  somewhat satisfied                 None                 very simple
#
#                gender  satisfaction_code  complexity_code
# 0     Man (cisgender)                  3                3
# 1     Man (cisgender)                  4                4
# 2   Woman (cisgender)                  5                1
# 3     Man (cisgender)                  4                3
# 4     Man (cisgender)                  4                4
# ..                ...                ...              ...
# 85  Woman (cisgender)                  5                1
# 86  Woman (cisgender)                  4                3
# 87    Man (cisgender)                  4                1
# 88  Woman (cisgender)                  4                4
# 89  Woman (cisgender)                  4                1
#
# [86 rows x 12 columns]

# %% [markdown]
# ## Satisfaction

# %%
user_satisfaction = users.groupby(['user_id', 'gender'])['satisfaction_code'].mean().reset_index()
user_satisfaction.rename(columns={'satisfaction_code': 'mean_satisfaction'}, inplace=True)
user_satisfaction
# Out:
#     user_id             gender  mean_satisfaction
# 0         6    Man (cisgender)           3.666667
# 1         8    Man (cisgender)           4.000000
# 2        11  Woman (cisgender)           5.000000
# 3        14    Man (cisgender)           4.000000
# 4        15    Man (cisgender)           4.000000
# 5        16  Woman (cisgender)           4.500000
# 6        25    Man (cisgender)           3.800000
# 7        28  Woman (cisgender)           3.750000
# 8        29  Woman (cisgender)           4.000000
# 9        31    Man (cisgender)           3.333333
# 10       34    Man (cisgender)           4.000000
# 11       46    Man (cisgender)           4.000000
# 12       47    Man (cisgender)           4.000000
# 13       48  Woman (cisgender)           4.000000
# 14       55  Woman (cisgender)           4.600000
# 15       56    Man (cisgender)           4.000000
# 16       60  Woman (cisgender)           4.200000
# 17       63  Woman (cisgender)           5.000000
# 18       65  Woman (cisgender)           4.000000
# 19       73  Woman (cisgender)           4.400000
# 20       77    Man (cisgender)           3.800000
# 21       79  Woman (cisgender)           4.200000
# 22       81    Man (cisgender)           4.500000
# 23       83    Man (cisgender)           4.333333
# 24       88    Man (cisgender)           4.500000
# 25       89  Woman (cisgender)           4.000000
# 26       90  Woman (cisgender)           3.000000
# 27       91    Man (cisgender)           4.000000
# 28       92    Man (cisgender)           4.250000

# %%
gender_means = user_satisfaction.groupby(['gender']).mean().reset_index()
gender_means
# Out:
#               gender    user_id  mean_satisfaction
# 0    Man (cisgender)  49.625000           4.011458
# 1  Woman (cisgender)  54.307692           4.203846

# %%
from helpers.statistical_tests import run_t_test_on_gender
run_t_test_on_gender(user_satisfaction, "mean_satisfaction", True)
# Out:
# mean_satisfaction:
#   T-statistic: -1.1695, p-value: 0.2576
#   Female: n=13, variance=0.2810
#   Male:   n=16, variance=0.0871

# %%
overall_mean = user_satisfaction['mean_satisfaction'].mean()
overall_mean
# Out:
# np.float64(4.097701149425288)

# %%
import scipy.stats as stats

# Suppose female and male are pandas Series of your group means
F = 0.2810 / 0.0871  # larger/smaller
df1 = 13 - 1
df2 = 16 - 1

# Two-tailed p-value
p_value = 2 * min(stats.f.cdf(F, df1, df2), 1 - stats.f.cdf(F, df1, df2))
print(f"F-statistic: {F:.4f}, p-value: {p_value:.4f}")
# Out:
# F-statistic: 3.2262, p-value: 0.0351

# %%
import statsmodels.formula.api as smf

model = smf.mixedlm(
    "satisfaction_code ~ gender",         # fixed effect
    users,                               # prompt-level DataFrame
    groups=users["user_id"]              # random user intercept
)
result = model.fit()
print(result.summary())
# Out:
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:              MixedLM   Dependent Variable:   satisfaction_code
# No. Observations:   86        Method:               REML
# No. Groups:         29        Scale:                0.6627
# Min. group size:    1         Log-Likelihood:       -108.1488
# Max. group size:    5         Converged:            Yes
# Mean group size:    3.0
# ---------------------------------------------------------------------
#                             Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   3.982    0.141 28.244 0.000  3.706  4.259
# gender[T.Woman (cisgender)] 0.196    0.197  0.992 0.321 -0.191  0.582
# Group Var                   0.047    0.081
# =====================================================================

# %% [markdown]
# - **Per-user variance**: Small, but still larger than the (not significant) gender effect.
# - **Gender effect**: Very minor and not reliable (the confidence interval includes zero).
# - **Most variation** in satisfaction is **unexplained by either gender or user identity** (most variance is “residual”).

# %% [markdown]
# ## Complexity

# %%
complexity = users.groupby(['user_id', 'gender'])['complexity_code'].mean().reset_index()
complexity.rename(columns={'complexity_code': 'mean_complexity'}, inplace=True)
complexity
# Out:
#     user_id             gender  mean_complexity
# 0         6    Man (cisgender)         3.333333
# 1         8    Man (cisgender)         4.000000
# 2        11  Woman (cisgender)         1.000000
# 3        14    Man (cisgender)         3.000000
# 4        15    Man (cisgender)         4.000000
# 5        16  Woman (cisgender)         3.000000
# 6        25    Man (cisgender)         2.600000
# 7        28  Woman (cisgender)         2.750000
# 8        29  Woman (cisgender)         3.000000
# 9        31    Man (cisgender)         3.333333
# 10       34    Man (cisgender)         2.500000
# 11       46    Man (cisgender)         4.000000
# 12       47    Man (cisgender)         3.000000
# 13       48  Woman (cisgender)         2.000000
# 14       55  Woman (cisgender)         4.200000
# 15       56    Man (cisgender)         1.666667
# 16       60  Woman (cisgender)         1.600000
# 17       63  Woman (cisgender)         2.000000
# 18       65  Woman (cisgender)         1.000000
# 19       73  Woman (cisgender)         3.000000
# 20       77    Man (cisgender)         2.000000
# 21       79  Woman (cisgender)         2.600000
# 22       81    Man (cisgender)         4.000000
# 23       83    Man (cisgender)         3.000000
# 24       88    Man (cisgender)         2.500000
# 25       89  Woman (cisgender)         4.500000
# 26       90  Woman (cisgender)         1.800000
# 27       91    Man (cisgender)         2.000000
# 28       92    Man (cisgender)         3.000000

# %%
compl_gender_means = complexity.groupby(['gender']).mean().reset_index()
compl_gender_means
# Out:
#               gender    user_id  mean_complexity
# 0    Man (cisgender)  49.625000         2.995833
# 1  Woman (cisgender)  54.307692         2.496154

# %%
from helpers.statistical_tests import run_t_test_on_gender
run_t_test_on_gender(complexity, "mean_complexity", True)
# Out:
# mean_complexity:
#   T-statistic: 1.4082, p-value: 0.1738
#   Female: n=13, variance=1.1677
#   Male:   n=16, variance=0.5773
