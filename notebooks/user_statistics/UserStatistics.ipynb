# %% [markdown]
# # User Statistics
#
# -  gender, age, experience, usage distribution
# - correlations:
# -   usage frequency and years of experience
# - usage distribution per gender
# - usage distributen per age group

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../../giicg.db")
users = pd.read_sql("Select * from users WHERE lastpage >= 3", conn)
conn.close()
users = users[users['gender'].isin(['Woman (cisgender)', 'Man (cisgender)'])]
users['work_exp_years'] = pd.to_numeric(users['work_exp_years'], errors='coerce')
users['study_year'] = pd.to_numeric(users['study_year'], errors='coerce')

# %% [markdown]
# ## Simple distributions

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_bar(data, column, title, xlabel, ylabel):
    ax = data[column].value_counts().sort_index().plot(kind="bar", figsize=(6,4))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Number of users per gender group
plot_bar(users, 'gender', "Users per Gender Group", "Gender", "Number of Users")

# Number of users per age class
plot_bar(users, 'age', "Users per Age Class", "Age Class", "Number of Users")

users['work_exp_years'] = pd.to_numeric(users['work_exp_years'], errors='coerce')
filtered = users[(users['work_exp_years'] <= 50) & (users['work_exp_years'].notna())]
bins = [-float('inf'), 1, 3, 5, 10, float('inf')]
labels = ['<=1', '1-3', '3-5', '5-10', '>10']
filtered['work_exp_group'] = pd.cut(filtered['work_exp_years'], bins=bins, labels=labels, right=True)
plot_bar(filtered, 'work_exp_group', "Users per Experience Group", "Experience Level", "Number of Users")

users['study_year'] = pd.to_numeric(users['study_year'], errors='coerce')
filtered = users[(users['study_year'] <= 50) & (users['study_year'].notna())]
bins = [-float('inf'), 1, 3, 5, 10, float('inf')]
labels = ['<=1', '1-3', '3-5', '5-10', '>10']
filtered['study_year_group'] = pd.cut(filtered['study_year'], bins=bins, labels=labels, right=True)
plot_bar(filtered, 'study_year_group', "Users per Study Year Group", "NUmber of study years", "Number of Users")

usage_order = [
    "Daily",
    "Several times a week",
    "Several times a month",
    "Several times a year",
    "Almost never"
]
users['usage_frequency'] = pd.Categorical(
    users['usage_frequency'],
    categories=usage_order,
    ordered=True
)
plot_bar(users, 'usage_frequency', "Users per Usage Group", "Usage frequency", "Number of Users")


# Number of users per usage group (assumed column: usage)
plot_bar(users, 'status', "Users per Status Group", "Status levels", "Number of Users")

education_order = [
    "High school diploma (Abitur or equivalent)",
    "Bachelor's degree",
    "Master's degree",
    "Phd",
]
users['education'] = pd.Categorical(
    users['education'],
    categories=education_order,
    ordered=True
)
plot_bar(users, 'education', "Users per Education Level", "Education level", "Number of Users")
# Out:
# /var/folders/w6/f5trsq6n2jx87f1mqgd_4vv80000gn/T/ipykernel_58522/3366796198.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['work_exp_group'] = pd.cut(filtered['work_exp_years'], bins=bins, labels=labels, right=True)
# /var/folders/w6/f5trsq6n2jx87f1mqgd_4vv80000gn/T/ipykernel_58522/3366796198.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['study_year_group'] = pd.cut(filtered['study_year'], bins=bins, labels=labels, right=True)

# %% [markdown]
# ## Demographic Data Gender Split

# %%
from matplotlib import pyplot as plt


def plot_bar_by_gender(data, column, title, xlabel, ylabel, categories=None, category_order=None):
    # Prepare and filter
    df = data.copy()
    if categories is not None:
        df = df[df[column].isin(categories)]
    df['gender'] = df['gender'].replace({'Woman (cisgender)': 'Woman', 'Man (cisgender)': 'Man'})

    # Group counts
    counts = df.groupby([column, 'gender'], observed=True).size().unstack(fill_value=0)

    # Convert counts to relative frequencies (proportions)
    # This calculates the proportion within each gender group
    relative_freq = counts.div(counts.sum(axis=0), axis=1)

    if category_order is not None:
        relative_freq = relative_freq.reindex(category_order)
    else:
        relative_freq = relative_freq.sort_index()

    ax = relative_freq.plot(
        kind="bar",
        figsize=(7, 4),
        color={'Woman': 'red', 'Man': 'blue'},
        width=0.8
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel.replace("Number of Users", "Relative Frequency"))
    ax.set_ylim(0, 1)  # Set y-axis to 0-1 range for proportions
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Gender')
    plt.tight_layout()
    plt.show()


# Example usage for each plot
plot_bar_by_gender(users, 'age', "Users per Age Class", "Age Class", "Number of Users")
plot_bar_by_gender(users, 'usage_frequency', "Users per Usage Group", "Usage Frequency", "Number of Users",
                   category_order=usage_order)
plot_bar_by_gender(users, 'status', "Users per Status Group", "Status", "Number of Users")

# For experience: use your filtered and binned DataFrame
filtered = users[(users['work_exp_years'] <= 50) & (users['work_exp_years'].notna())]
filtered['work_exp_group'] = pd.cut(filtered['work_exp_years'], bins=bins, labels=labels, right=True)
plot_bar_by_gender(filtered, 'work_exp_group', "Users per Experience Group", "Experience Level", "Number of Users",
                   category_order=labels)

# For study years
filtered = users[(users['study_year'] <= 50) & (users['study_year'].notna())]
filtered['study_year_group'] = pd.cut(filtered['study_year'], bins=bins, labels=labels, right=True)
plot_bar_by_gender(filtered, 'study_year_group', "Users per Study Year Group", "Study Year Group", "Number of Users",
                   category_order=labels)

# For education
plot_bar_by_gender(users, 'education', "Users per Education Level", "Education Level", "Number of Users",
                   category_order=education_order)
# Out:
# /var/folders/w6/f5trsq6n2jx87f1mqgd_4vv80000gn/T/ipykernel_58522/4115452056.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['work_exp_group'] = pd.cut(filtered['work_exp_years'], bins=bins, labels=labels, right=True)
# /var/folders/w6/f5trsq6n2jx87f1mqgd_4vv80000gn/T/ipykernel_58522/4115452056.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['study_year_group'] = pd.cut(filtered['study_year'], bins=bins, labels=labels, right=True)

# %%
import pandas as pd
from scipy.stats import chi2_contingency, fisher_exact

# Assume 'users' DataFrame has columns 'gender' and 'usage_frequency'
freq_table = pd.crosstab(users['gender'], users['usage_frequency'])
chi2, p, dof, expected = chi2_contingency(freq_table)
print("Chi-square statistic:", chi2)
print("p-value:", p)

import pandas as pd
from scipy.stats import fisher_exact

# Assume 'users' DataFrame has columns: 'gender' and 'usage_frequency'
categories = users['usage_frequency'].dropna().unique()

# Only keep men/women cis
users_sub = users[users['gender'].isin(['Man (cisgender)', 'Woman (cisgender)'])].copy()

results = []

for cat in categories:
    # 2x2 contingency table
    # Row 1: Woman (cisgender), Row 2: Man (cisgender)
    # Col 1: Category present, Col 2: Other categories
    table = [
        [
            ((users_sub['gender'] == 'Woman (cisgender)') & (users_sub['usage_frequency'] == cat)).sum(),
            ((users_sub['gender'] == 'Woman (cisgender)') & (users_sub['usage_frequency'] != cat)).sum()
        ],
        [
            ((users_sub['gender'] == 'Man (cisgender)') & (users_sub['usage_frequency'] == cat)).sum(),
            ((users_sub['gender'] == 'Man (cisgender)') & (users_sub['usage_frequency'] != cat)).sum()
        ]
    ]
    # Only test if both rows and columns have >0
    if all(sum(row) > 0 for row in table) and all(sum(col) > 0 for col in zip(*table)):
        odds_ratio, p = fisher_exact(table)
        results.append({'category': cat, 'odds_ratio': odds_ratio, 'p_value': p, 'table': table})
    else:
        results.append({'category': cat, 'odds_ratio': None, 'p_value': None, 'table': table})

# Print or convert to DataFrame for easier viewing
results_df = pd.DataFrame(results)
print(results_df[['category', 'p_value', 'odds_ratio', 'table']])
# Out:
# Chi-square statistic: 8.116736596736597
# p-value: 0.0436597257929016
#                 category   p_value  odds_ratio               table
# 0                  Daily  0.054571    0.159091   [[2, 11], [8, 7]]
# 1   Several times a week  0.245810    3.208333   [[7, 6], [4, 11]]
# 2  Several times a month  0.152778    6.222222   [[4, 9], [1, 14]]
# 3   Several times a year  0.484127    0.000000  [[0, 13], [2, 13]]

# %% [markdown]
# ## LLM Usage gender split

# %%
response_order_agree = [
    "Strongly disagree",
    "Disagree",
    "Neutral",
    "Agree",
    "Strongly Agree"
]

response_order_yes_no = [
    "Yes",
    "No",
]

plot_bar_by_gender(users, 'llms_helpful', "LLMs are helpful for writing code. ", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_enjoy', "I enjoy using LLMs in my work or for studying.", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_go_back', "I would like to go back to the time before they existed.", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_faster', "I have become faster at learning new programming skills through using LLMs.", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_slower', "I have become slower at learning new programming skills through using LLMs.", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_prompt_engineering', "I am employing specific prompting techniques when prompting LLMs.", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_approach', "My way to approach new programming challenges has changed through using LLMs.", "Reply", "Number of Users", category_order=response_order_agree)
users
# Out:
#     user_id  lastpage        seed    age  \
# 0         6         8  1673258229  19-25
# 1         8         8  1155338690  19-25
# 2        11         8  1462336171  26-30
# 3        15         8  1937126585  26-30
# 4        16         8  1979098288  19-25
# 5        25         8  1442054330  26-30
# 6        28         8  1943323569  31-35
# 7        29         8   978929840  26-30
# 9        31         8  1395672098  36-40
# 10       34         8  1374827140  51-60
# 11       46         8   217230409  31-35
# 12       47         8   767975588  31-35
# 13       48         8  2031177185  19-25
# 14       55         8  2025687955  26-30
# 15       56         8  1165225262  26-30
# 16       60         8  1849077149  19-25
# 17       63         3   831754724  26-30
# 18       65         8   151250910  19-25
# 19       73         8   712726586  31-35
# 20       77         8  1057823690  26-30
# 21       79         8  2003765003  19-25
# 22       81         8   721420406  26-30
# 23       83         8  1653248369  19-25
# 25       88         8  1547460079  19-25
# 26       89         8  1068307423  26-30
# 27       90         8  2010148169  26-30
# 28       91         8   793167065  31-35
# 29       92         8   177546188  36-40
#
#                                      education   status  \
# 0                            Bachelor's degree     Both
# 1                            Bachelor's degree     Both
# 2                            Bachelor's degree     Both
# 3                                          Phd  Working
# 4                            Bachelor's degree  Student
# 5                            Bachelor's degree  Working
# 6                                          Phd  Working
# 7                              Master's degree  Student
# 9   High school diploma (Abitur or equivalent)  Working
# 10                             Master's degree  Working
# 11                           Bachelor's degree  Working
# 12                           Bachelor's degree  Working
# 13                           Bachelor's degree  Student
# 14                           Bachelor's degree     Both
# 15                             Master's degree  Working
# 16  High school diploma (Abitur or equivalent)  Student
# 17                           Bachelor's degree     Both
# 18                           Bachelor's degree  Student
# 19                           Bachelor's degree  Student
# 20                             Master's degree     Both
# 21                             Master's degree  Working
# 22                           Bachelor's degree     Both
# 23  High school diploma (Abitur or equivalent)     Both
# 25  High school diploma (Abitur or equivalent)  Student
# 26                                         Phd  Working
# 27                             Master's degree     Both
# 28                           Bachelor's degree     Both
# 29                             Master's degree  Working
#
#                                           study_field  study_year  \
# 0                                 Data Science (M.Sc)      2026.0
# 1                   Computer-aided design (CAD) (B.A)         5.0
# 2                                  Informatik (B.Sc.)         4.0
# 3                                                None         NaN
# 4                        Computer Engineering (M.Sc.)         2.0
# 5                                                None         NaN
# 6                                                None         NaN
# 7                             PhD in Computer Science         3.0
# 9                                                None         NaN
# 10                                               None         NaN
# 11                                               None         NaN
# 12                                               None         NaN
# 13             Information Systems Management (M.Sc.)         6.0
# 14                                   Computer Science         4.0
# 15                                               None         NaN
# 16                                     Physik (B.Sc.)         5.0
# 17  Remote Sensing, GeoInformation and Visualisati...         6.0
# 18                                    Geoinformation          2.0
# 19                           Computer Science (M.Sc.)         8.0
# 20             Theoretical physics, Cosmology (Ph.D.)        10.0
# 21                                               None         NaN
# 22                                     Remote Sensing         6.0
# 23                            Computer Science (B.Sc)         3.0
# 25                      Wirtschaftsinformatik (B.Sc.)         2.0
# 26                                               None         NaN
# 27                            Computer Science (M.Sc)         5.0
# 28                Audiokommunikation und -technologie         8.0
# 29                                               None         NaN
#
#                                            work_field  work_exp_years  ...  \
# 0                  Data engineer in auomotive company             3.0  ...
# 1                                     Computer vision             1.0  ...
# 2                                  Research assistant             1.0  ...
# 3   Immunology research and biomedical analytics s...             6.0  ...
# 4                                                None             NaN  ...
# 5                    Software engineering for the web             6.0  ...
# 6   Research on LLMs for transparency and responsi...             5.0  ...
# 7                                                None             NaN  ...
# 9                                Software Engineering            22.0  ...
# 10          Interface design and Software architeture            20.0  ...
# 11      Software engineering in an e-commerce company            12.0  ...
# 12                                     Graphic Design            55.0  ...
# 13                                               None             NaN  ...
# 14                               Software engineering             2.0  ...
# 15                                         Researcher             9.0  ...
# 16                                               None             NaN  ...
# 17    Data analysis and visualisation for a newspaper             2.0  ...
# 18                                               None             NaN  ...
# 19                                               None             NaN  ...
# 20  Post Doctoral researcher in cosmology/astrophy...             1.0  ...
# 21         Software developer/Geoinformatics Engineer             0.0  ...
# 22  Project Developer Working Student in Energy In...             1.0  ...
# 23                           Fullstack Webdevelopment             3.0  ...
# 25                                               None             NaN  ...
# 26              Senior NLP researcher at a University             6.0  ...
# 27  Software Engineering intern at a fish louse la...             2.0  ...
# 28                                Radio & digital Art             6.0  ...
# 29                                 Research Associate             3.0  ...
#
#    llms_ethical_concerns llms_ec_bias llms_ec_discrimination  \
# 0                  Agree           No                     No
# 1                  Agree          Yes                     No
# 2                  Agree          Yes                    Yes
# 3                  Agree          Yes                     No
# 4                  Agree          Yes                    Yes
# 5                Neutral         None                   None
# 6                  Agree          Yes                     No
# 7                  Agree          Yes                     No
# 9         Strongly Agree          Yes                    Yes
# 10                 Agree           No                     No
# 11        Strongly Agree          Yes                    Yes
# 12        Strongly Agree          Yes                     No
# 13        Strongly Agree          Yes                    Yes
# 14                 Agree           No                     No
# 15                  None         None                   None
# 16        Strongly Agree          Yes                    Yes
# 17                  None         None                   None
# 18                 Agree           No                     No
# 19                 Agree          Yes                    Yes
# 20                 Agree          Yes                    Yes
# 21               Neutral         None                   None
# 22                 Agree          Yes                    Yes
# 23        Strongly Agree          Yes                     No
# 25                 Agree           No                     No
# 26        Strongly Agree          Yes                    Yes
# 27               Neutral         None                   None
# 28                 Agree          Yes                    Yes
# 29        Strongly Agree          Yes                    Yes
#
#    llms_ec_skill_loss llms_ec_learn_less llms_ec_diversity_loss llms_ec_other  \
# 0                  No                 No                     No           Yes
# 1                 Yes                Yes                     No            No
# 2                 Yes                Yes                    Yes            No
# 3                 Yes                Yes                    Yes            No
# 4                  No                 No                    Yes            No
# 5                None               None                   None          None
# 6                 Yes                 No                    Yes            No
# 7                  No                Yes                    Yes            No
# 9                 Yes                 No                    Yes           Yes
# 10                Yes                 No                     No            No
# 11                Yes                Yes                    Yes            No
# 12                Yes                Yes                    Yes            No
# 13                Yes                 No                    Yes            No
# 14                Yes                 No                    Yes            No
# 15               None               None                   None          None
# 16                Yes                 No                    Yes            No
# 17               None               None                   None          None
# 18                Yes                 No                    Yes            No
# 19                Yes                Yes                     No            No
# 20                 No                 No                     No           Yes
# 21               None               None                   None          None
# 22                 No                 No                    Yes            No
# 23                Yes                Yes                    Yes            No
# 25                Yes                Yes                    Yes            No
# 26                Yes                 No                     No            No
# 27               None               None                   None          None
# 28                 No                 No                     No           Yes
# 29                Yes                Yes                    Yes            No
#
#                                   llms_other_concerns  \
# 0     LLMs can use code protected from specific usage
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 9   LLMs might reduce the motivation to publish kn...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Violation of intellectual property, unemployme...
# 21                                               None
# 22                                               None
# 23                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                             copyright infringement
# 29                                               None
#
#                                   llms_other_thoughts usage_frequency_num
# 0                                                None                   5
# 1                                                None                   4
# 2                                                None                   4
# 3   Programming, problem solving and comprehension...                   5
# 4   Sometimes when I am in a hurry I don´t check p...                   4
# 5   It produces a lot of very bad unmaintainable c...                   5
# 6       They might reduce people's creative thinking.                   4
# 7                                                None                   3
# 9   As a coding assistant, at the current state, L...                   4
# 10                   Too many to write into this box.                   5
# 11                                               None                   2
# 12  Ich finde für allgemeine Anwendungen oder Bere...                   2
# 13  - tbh it accelerates processes a lot\n- LLMs m...                   3
# 14                                               None                   5
# 15                                               None                   4
# 16                                               None                   4
# 17                                               None                   4
# 18  From a beginner’s perspective it’s temping to ...                   3
# 19  I fear that this will lead to more stress in t...                   4
# 20  LLMs are amazing for speeding up simple/mundan...                   5
# 21                                               None                   5
# 22  If you do something important always be critia...                   5
# 23  Having LLM written code is in my experience al...                   5
# 25  Carelessly using LLMs might introduce dangerou...                   4
# 26  My attention span on long text is not as good ...                   3
# 27  Can be a useful tool, but it's definitely not ...                   4
# 28                                               None                   3
# 29                                               None                   5
#
# [28 rows x 36 columns]

# %% [markdown]
# ## Additional questions gender split

# %%
response_order_agree = [
    "Strongly disagree",
    "Disagree",
    "Neutral",
    "Agree",
    "Strongly Agree"
]

response_order_yes_no = [
    "Yes",
    "No",
]

plot_bar_by_gender(users, 'llms_ethical_concerns', "I have ethical concerns about the technology", "Reply", "Number of Users", category_order=response_order_agree)
plot_bar_by_gender(users, 'llms_ec_bias', "LLMs can reproduce bias", "Reply", "Number of Users", category_order=response_order_yes_no)
plot_bar_by_gender(users, 'llms_ec_discrimination', "LLMs can reproduce discrimination", "Reply", "Number of Users", category_order=response_order_yes_no)
plot_bar_by_gender(users, 'llms_ec_skill_loss', "LLMs can lead to a loss of skill", "Reply", "Number of Users", category_order=response_order_yes_no)
plot_bar_by_gender(users, 'llms_ec_learn_less', "LLM users can learn less", "Reply", "Number of Users", category_order=response_order_yes_no)
plot_bar_by_gender(users, 'llms_ec_diversity_loss', "LLMs can lead to a loss of diversity in coding and writing styles", "Reply", "Number of Users", category_order=response_order_yes_no)
plot_bar_by_gender(users, 'llms_ec_other', "I have other concerns", "Reply", "Number of Users", category_order=response_order_yes_no)
users
# Out:
#     user_id  lastpage        seed    age  \
# 0         6         8  1673258229  19-25
# 1         8         8  1155338690  19-25
# 2        11         8  1462336171  26-30
# 3        15         8  1937126585  26-30
# 4        16         8  1979098288  19-25
# 5        25         8  1442054330  26-30
# 6        28         8  1943323569  31-35
# 7        29         8   978929840  26-30
# 9        31         8  1395672098  36-40
# 10       34         8  1374827140  51-60
# 11       46         8   217230409  31-35
# 12       47         8   767975588  31-35
# 13       48         8  2031177185  19-25
# 14       55         8  2025687955  26-30
# 15       56         8  1165225262  26-30
# 16       60         8  1849077149  19-25
# 17       63         3   831754724  26-30
# 18       65         8   151250910  19-25
# 19       73         8   712726586  31-35
# 20       77         8  1057823690  26-30
# 21       79         8  2003765003  19-25
# 22       81         8   721420406  26-30
# 23       83         8  1653248369  19-25
# 25       88         8  1547460079  19-25
# 26       89         8  1068307423  26-30
# 27       90         8  2010148169  26-30
# 28       91         8   793167065  31-35
# 29       92         8   177546188  36-40
#
#                                      education   status  \
# 0                            Bachelor's degree     Both
# 1                            Bachelor's degree     Both
# 2                            Bachelor's degree     Both
# 3                                          Phd  Working
# 4                            Bachelor's degree  Student
# 5                            Bachelor's degree  Working
# 6                                          Phd  Working
# 7                              Master's degree  Student
# 9   High school diploma (Abitur or equivalent)  Working
# 10                             Master's degree  Working
# 11                           Bachelor's degree  Working
# 12                           Bachelor's degree  Working
# 13                           Bachelor's degree  Student
# 14                           Bachelor's degree     Both
# 15                             Master's degree  Working
# 16  High school diploma (Abitur or equivalent)  Student
# 17                           Bachelor's degree     Both
# 18                           Bachelor's degree  Student
# 19                           Bachelor's degree  Student
# 20                             Master's degree     Both
# 21                             Master's degree  Working
# 22                           Bachelor's degree     Both
# 23  High school diploma (Abitur or equivalent)     Both
# 25  High school diploma (Abitur or equivalent)  Student
# 26                                         Phd  Working
# 27                             Master's degree     Both
# 28                           Bachelor's degree     Both
# 29                             Master's degree  Working
#
#                                           study_field  study_year  \
# 0                                 Data Science (M.Sc)      2026.0
# 1                   Computer-aided design (CAD) (B.A)         5.0
# 2                                  Informatik (B.Sc.)         4.0
# 3                                                None         NaN
# 4                        Computer Engineering (M.Sc.)         2.0
# 5                                                None         NaN
# 6                                                None         NaN
# 7                             PhD in Computer Science         3.0
# 9                                                None         NaN
# 10                                               None         NaN
# 11                                               None         NaN
# 12                                               None         NaN
# 13             Information Systems Management (M.Sc.)         6.0
# 14                                   Computer Science         4.0
# 15                                               None         NaN
# 16                                     Physik (B.Sc.)         5.0
# 17  Remote Sensing, GeoInformation and Visualisati...         6.0
# 18                                    Geoinformation          2.0
# 19                           Computer Science (M.Sc.)         8.0
# 20             Theoretical physics, Cosmology (Ph.D.)        10.0
# 21                                               None         NaN
# 22                                     Remote Sensing         6.0
# 23                            Computer Science (B.Sc)         3.0
# 25                      Wirtschaftsinformatik (B.Sc.)         2.0
# 26                                               None         NaN
# 27                            Computer Science (M.Sc)         5.0
# 28                Audiokommunikation und -technologie         8.0
# 29                                               None         NaN
#
#                                            work_field  work_exp_years  ...  \
# 0                  Data engineer in auomotive company             3.0  ...
# 1                                     Computer vision             1.0  ...
# 2                                  Research assistant             1.0  ...
# 3   Immunology research and biomedical analytics s...             6.0  ...
# 4                                                None             NaN  ...
# 5                    Software engineering for the web             6.0  ...
# 6   Research on LLMs for transparency and responsi...             5.0  ...
# 7                                                None             NaN  ...
# 9                                Software Engineering            22.0  ...
# 10          Interface design and Software architeture            20.0  ...
# 11      Software engineering in an e-commerce company            12.0  ...
# 12                                     Graphic Design            55.0  ...
# 13                                               None             NaN  ...
# 14                               Software engineering             2.0  ...
# 15                                         Researcher             9.0  ...
# 16                                               None             NaN  ...
# 17    Data analysis and visualisation for a newspaper             2.0  ...
# 18                                               None             NaN  ...
# 19                                               None             NaN  ...
# 20  Post Doctoral researcher in cosmology/astrophy...             1.0  ...
# 21         Software developer/Geoinformatics Engineer             0.0  ...
# 22  Project Developer Working Student in Energy In...             1.0  ...
# 23                           Fullstack Webdevelopment             3.0  ...
# 25                                               None             NaN  ...
# 26              Senior NLP researcher at a University             6.0  ...
# 27  Software Engineering intern at a fish louse la...             2.0  ...
# 28                                Radio & digital Art             6.0  ...
# 29                                 Research Associate             3.0  ...
#
#                                llms_describe_approach llms_ethical_concerns  \
# 0                                  Faster development                 Agree
# 1                                                None                 Agree
# 2                                                None                 Agree
# 3   I can now write production code in languages t...                 Agree
# 4   I am brainstorming "together" with the LLM bef...                 Agree
# 5                                                None               Neutral
# 6   I am now mostly describing my problems in natu...                 Agree
# 7   I use LLMs to consult me regarding the setup o...                 Agree
# 9   If the challenges don't look interesting to me...        Strongly Agree
# 10                                               None                 Agree
# 11                                               None        Strongly Agree
# 12  - bin sehr faul geworden was lösen von Coding-...        Strongly Agree
# 13  Before I started using LLMs, i often got stuck...        Strongly Agree
# 14                                               None                 Agree
# 15                                               None                  None
# 16  For simple programming, it is faster for me to...        Strongly Agree
# 17                                               None                  None
# 18               It’s quicker to get into the topics.                 Agree
# 19  I've forgotten how to program on my own. And I...                 Agree
# 20  The first step is usually trying to see how fa...                 Agree
# 21                                               None               Neutral
# 22  I do not start from scratch anymore. I let Cha...                 Agree
# 23  LLMs enable me to get specific information rel...        Strongly Agree
# 25  for tasks that are not interesting to me i let...                 Agree
# 26  Very often now it's a lot of vibe coding for n...        Strongly Agree
# 27  I use my brain less and I have become lazier, ...               Neutral
# 28                                               None                 Agree
# 29                                               None        Strongly Agree
#
#    llms_ec_bias llms_ec_discrimination llms_ec_skill_loss llms_ec_learn_less  \
# 0            No                     No                 No                 No
# 1           Yes                     No                Yes                Yes
# 2           Yes                    Yes                Yes                Yes
# 3           Yes                     No                Yes                Yes
# 4           Yes                    Yes                 No                 No
# 5          None                   None               None               None
# 6           Yes                     No                Yes                 No
# 7           Yes                     No                 No                Yes
# 9           Yes                    Yes                Yes                 No
# 10           No                     No                Yes                 No
# 11          Yes                    Yes                Yes                Yes
# 12          Yes                     No                Yes                Yes
# 13          Yes                    Yes                Yes                 No
# 14           No                     No                Yes                 No
# 15         None                   None               None               None
# 16          Yes                    Yes                Yes                 No
# 17         None                   None               None               None
# 18           No                     No                Yes                 No
# 19          Yes                    Yes                Yes                Yes
# 20          Yes                    Yes                 No                 No
# 21         None                   None               None               None
# 22          Yes                    Yes                 No                 No
# 23          Yes                     No                Yes                Yes
# 25           No                     No                Yes                Yes
# 26          Yes                    Yes                Yes                 No
# 27         None                   None               None               None
# 28          Yes                    Yes                 No                 No
# 29          Yes                    Yes                Yes                Yes
#
#    llms_ec_diversity_loss llms_ec_other  \
# 0                      No           Yes
# 1                      No            No
# 2                     Yes            No
# 3                     Yes            No
# 4                     Yes            No
# 5                    None          None
# 6                     Yes            No
# 7                     Yes            No
# 9                     Yes           Yes
# 10                     No            No
# 11                    Yes            No
# 12                    Yes            No
# 13                    Yes            No
# 14                    Yes            No
# 15                   None          None
# 16                    Yes            No
# 17                   None          None
# 18                    Yes            No
# 19                     No            No
# 20                     No           Yes
# 21                   None          None
# 22                    Yes            No
# 23                    Yes            No
# 25                    Yes            No
# 26                     No            No
# 27                   None          None
# 28                     No           Yes
# 29                    Yes            No
#
#                                   llms_other_concerns  \
# 0     LLMs can use code protected from specific usage
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 9   LLMs might reduce the motivation to publish kn...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Violation of intellectual property, unemployme...
# 21                                               None
# 22                                               None
# 23                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                             copyright infringement
# 29                                               None
#
#                                   llms_other_thoughts
# 0                                                None
# 1                                                None
# 2                                                None
# 3   Programming, problem solving and comprehension...
# 4   Sometimes when I am in a hurry I don´t check p...
# 5   It produces a lot of very bad unmaintainable c...
# 6       They might reduce people's creative thinking.
# 7                                                None
# 9   As a coding assistant, at the current state, L...
# 10                   Too many to write into this box.
# 11                                               None
# 12  Ich finde für allgemeine Anwendungen oder Bere...
# 13  - tbh it accelerates processes a lot\n- LLMs m...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  From a beginner’s perspective it’s temping to ...
# 19  I fear that this will lead to more stress in t...
# 20  LLMs are amazing for speeding up simple/mundan...
# 21                                               None
# 22  If you do something important always be critia...
# 23  Having LLM written code is in my experience al...
# 25  Carelessly using LLMs might introduce dangerou...
# 26  My attention span on long text is not as good ...
# 27  Can be a useful tool, but it's definitely not ...
# 28                                               None
# 29                                               None
#
# [28 rows x 35 columns]

# %% [markdown]
# ## Correlations

# %%
import seaborn as sns

freq_order = [
    "Daily",
    "Several times a week",
    "Several times a month",
    "Several times a year",
    "Almost never"
]
# Map each category to a numeric value (e.g., 5 for "Daily", 1 for "Almost never")
freq_map = {cat: i for i, cat in enumerate(reversed(freq_order), 1)}

users["usage_frequency_num"] = users["usage_frequency"].map(freq_map)

# Now you can compute the correlation
# Make sure to also handle work_exp_years as numeric
users["work_exp_years"] = pd.to_numeric(users["work_exp_years"], errors='coerce')
filtered = users[users["work_exp_years"] <= 50]
df_corr = filtered.dropna(subset=["usage_frequency_num", "work_exp_years"])
correlation = df_corr["usage_frequency_num"].corr(df_corr["work_exp_years"])

print(f"Correlation between usage_frequency and work_exp_years: {correlation:.3f}")

# Plot scatter plot
plt.figure(figsize=(7,5))
sns.regplot(x='work_exp_years', y='usage_frequency_num', data=df_corr, scatter_kws={'alpha':0.7})
plt.title('Usage Frequency vs. Work Experience (Years)')
plt.xlabel('Work Experience (Years)')
plt.ylabel('Usage Frequency')
plt.tight_layout()
plt.show()

df_corr
# Out:
# Correlation between usage_frequency and work_exp_years: -0.212
#     user_id  lastpage        seed    age  \
# 0         6         8  1673258229  19-25
# 1         8         8  1155338690  19-25
# 2        11         8  1462336171  26-30
# 3        15         8  1937126585  26-30
# 5        25         8  1442054330  26-30
# 6        28         8  1943323569  31-35
# 9        31         8  1395672098  36-40
# 10       34         8  1374827140  51-60
# 11       46         8   217230409  31-35
# 14       55         8  2025687955  26-30
# 15       56         8  1165225262  26-30
# 17       63         3   831754724  26-30
# 20       77         8  1057823690  26-30
# 21       79         8  2003765003  19-25
# 22       81         8   721420406  26-30
# 23       83         8  1653248369  19-25
# 24       84         8  1744038345  36-40
# 26       89         8  1068307423  26-30
# 27       90         8  2010148169  26-30
# 28       91         8   793167065  31-35
# 29       92         8   177546188  36-40
#
#                                      education   status  \
# 0                            Bachelor's degree     Both
# 1                            Bachelor's degree     Both
# 2                            Bachelor's degree     Both
# 3                                          Phd  Working
# 5                            Bachelor's degree  Working
# 6                                          Phd  Working
# 9   High school diploma (Abitur or equivalent)  Working
# 10                             Master's degree  Working
# 11                           Bachelor's degree  Working
# 14                           Bachelor's degree     Both
# 15                             Master's degree  Working
# 17                           Bachelor's degree     Both
# 20                             Master's degree     Both
# 21                             Master's degree  Working
# 22                           Bachelor's degree     Both
# 23  High school diploma (Abitur or equivalent)     Both
# 24                             Master's degree  Working
# 26                                         Phd  Working
# 27                             Master's degree     Both
# 28                           Bachelor's degree     Both
# 29                             Master's degree  Working
#
#                                           study_field  study_year  \
# 0                                 Data Science (M.Sc)      2026.0
# 1                   Computer-aided design (CAD) (B.A)         5.0
# 2                                  Informatik (B.Sc.)         4.0
# 3                                                None         NaN
# 5                                                None         NaN
# 6                                                None         NaN
# 9                                                None         NaN
# 10                                               None         NaN
# 11                                               None         NaN
# 14                                   Computer Science         4.0
# 15                                               None         NaN
# 17  Remote Sensing, GeoInformation and Visualisati...         6.0
# 20             Theoretical physics, Cosmology (Ph.D.)        10.0
# 21                                               None         NaN
# 22                                     Remote Sensing         6.0
# 23                            Computer Science (B.Sc)         3.0
# 24                                               None         NaN
# 26                                               None         NaN
# 27                            Computer Science (M.Sc)         5.0
# 28                Audiokommunikation und -technologie         8.0
# 29                                               None         NaN
#
#                                            work_field  work_exp_years  ...  \
# 0                  Data engineer in auomotive company             3.0  ...
# 1                                     Computer vision             1.0  ...
# 2                                  Research assistant             1.0  ...
# 3   Immunology research and biomedical analytics s...             6.0  ...
# 5                    Software engineering for the web             6.0  ...
# 6   Research on LLMs for transparency and responsi...             5.0  ...
# 9                                Software Engineering            22.0  ...
# 10          Interface design and Software architeture            20.0  ...
# 11      Software engineering in an e-commerce company            12.0  ...
# 14                               Software engineering             2.0  ...
# 15                                         Researcher             9.0  ...
# 17    Data analysis and visualisation for a newspaper             2.0  ...
# 20  Post Doctoral researcher in cosmology/astrophy...             1.0  ...
# 21         Software developer/Geoinformatics Engineer             0.0  ...
# 22  Project Developer Working Student in Energy In...             1.0  ...
# 23                           Fullstack Webdevelopment             3.0  ...
# 24                 Qualitative Research at University             4.0  ...
# 26              Senior NLP researcher at a University             6.0  ...
# 27  Software Engineering intern at a fish louse la...             2.0  ...
# 28                                Radio & digital Art             6.0  ...
# 29                                 Research Associate             3.0  ...
#
#    llms_ethical_concerns llms_ec_bias llms_ec_discrimination  \
# 0                  Agree           No                     No
# 1                  Agree          Yes                     No
# 2                  Agree          Yes                    Yes
# 3                  Agree          Yes                     No
# 5                Neutral         None                   None
# 6                  Agree          Yes                     No
# 9         Strongly Agree          Yes                    Yes
# 10                 Agree           No                     No
# 11        Strongly Agree          Yes                    Yes
# 14                 Agree           No                     No
# 15                  None         None                   None
# 17                  None         None                   None
# 20                 Agree          Yes                    Yes
# 21               Neutral         None                   None
# 22                 Agree          Yes                    Yes
# 23        Strongly Agree          Yes                     No
# 24        Strongly Agree          Yes                    Yes
# 26        Strongly Agree          Yes                    Yes
# 27               Neutral         None                   None
# 28                 Agree          Yes                    Yes
# 29        Strongly Agree          Yes                    Yes
#
#    llms_ec_skill_loss llms_ec_learn_less llms_ec_diversity_loss llms_ec_other  \
# 0                  No                 No                     No           Yes
# 1                 Yes                Yes                     No            No
# 2                 Yes                Yes                    Yes            No
# 3                 Yes                Yes                    Yes            No
# 5                None               None                   None          None
# 6                 Yes                 No                    Yes            No
# 9                 Yes                 No                    Yes           Yes
# 10                Yes                 No                     No            No
# 11                Yes                Yes                    Yes            No
# 14                Yes                 No                    Yes            No
# 15               None               None                   None          None
# 17               None               None                   None          None
# 20                 No                 No                     No           Yes
# 21               None               None                   None          None
# 22                 No                 No                    Yes            No
# 23                Yes                Yes                    Yes            No
# 24                 No                 No                    Yes            No
# 26                Yes                 No                     No            No
# 27               None               None                   None          None
# 28                 No                 No                     No           Yes
# 29                Yes                Yes                    Yes            No
#
#                                   llms_other_concerns  \
# 0     LLMs can use code protected from specific usage
# 1                                                None
# 2                                                None
# 3                                                None
# 5                                                None
# 6                                                None
# 9   LLMs might reduce the motivation to publish kn...
# 10                                               None
# 11                                               None
# 14                                               None
# 15                                               None
# 17                                               None
# 20  Violation of intellectual property, unemployme...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 26                                               None
# 27                                               None
# 28                             copyright infringement
# 29                                               None
#
#                                   llms_other_thoughts usage_frequency_num
# 0                                                None                   5
# 1                                                None                   4
# 2                                                None                   4
# 3   Programming, problem solving and comprehension...                   5
# 5   It produces a lot of very bad unmaintainable c...                   5
# 6       They might reduce people's creative thinking.                   4
# 9   As a coding assistant, at the current state, L...                   4
# 10                   Too many to write into this box.                   5
# 11                                               None                   2
# 14                                               None                   5
# 15                                               None                   4
# 17                                               None                   4
# 20  LLMs are amazing for speeding up simple/mundan...                   5
# 21                                               None                   5
# 22  If you do something important always be critia...                   5
# 23  Having LLM written code is in my experience al...                   5
# 24  I am most concerned with centralization to act...                   3
# 26  My attention span on long text is not as good ...                   3
# 27  Can be a useful tool, but it's definitely not ...                   4
# 28                                               None                   3
# 29                                               None                   5
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Experience Years and Gender

# %%
import seaborn as sns

freq_order = [
    "Daily",
    "Several times a week",
    "Several times a month",
    "Several times a year",
    "Almost never"
]
# Map each category to a numeric value (e.g., 5 for "Daily", 1 for "Almost never")
freq_map = {cat: i for i, cat in enumerate(reversed(freq_order), 1)}

users["usage_frequency_num"] = users["usage_frequency"].map(freq_map)

# Now you can compute the correlation
# Make sure to also handle work_exp_years as numeric
users["work_exp_years"] = pd.to_numeric(users["work_exp_years"], errors='coerce')
filtered = users[users["work_exp_years"] <= 50]
df_corr = filtered.dropna(subset=["usage_frequency_num", "work_exp_years"])
correlation = df_corr["usage_frequency_num"].corr(df_corr["work_exp_years"])

print(f"Correlation between usage_frequency and work_exp_years: {correlation:.3f}")

# Plot scatter plot
plt.figure(figsize=(7,5))
sns.regplot(x='work_exp_years', y='usage_frequency_num', data=df_corr, scatter_kws={'alpha':0.7})
plt.title('Usage Frequency vs. Work Experience (Years)')
plt.xlabel('Work Experience (Years)')
plt.ylabel('Usage Frequency')
plt.tight_layout()
plt.show()

df_corr
# Out:
# Correlation between usage_frequency and work_exp_years: -0.243
#     user_id  lastpage        seed    age  \
# 0         6         8  1673258229  19-25
# 1         8         8  1155338690  19-25
# 2        11         8  1462336171  26-30
# 3        15         8  1937126585  26-30
# 5        25         8  1442054330  26-30
# 6        28         8  1943323569  31-35
# 9        31         8  1395672098  36-40
# 10       34         8  1374827140  51-60
# 11       46         8   217230409  31-35
# 14       55         8  2025687955  26-30
# 15       56         8  1165225262  26-30
# 17       63         3   831754724  26-30
# 20       77         8  1057823690  26-30
# 21       79         8  2003765003  19-25
# 22       81         8   721420406  26-30
# 23       83         8  1653248369  19-25
# 26       89         8  1068307423  26-30
# 27       90         8  2010148169  26-30
# 28       91         8   793167065  31-35
# 29       92         8   177546188  36-40
#
#                                      education   status  \
# 0                            Bachelor's degree     Both
# 1                            Bachelor's degree     Both
# 2                            Bachelor's degree     Both
# 3                                          Phd  Working
# 5                            Bachelor's degree  Working
# 6                                          Phd  Working
# 9   High school diploma (Abitur or equivalent)  Working
# 10                             Master's degree  Working
# 11                           Bachelor's degree  Working
# 14                           Bachelor's degree     Both
# 15                             Master's degree  Working
# 17                           Bachelor's degree     Both
# 20                             Master's degree     Both
# 21                             Master's degree  Working
# 22                           Bachelor's degree     Both
# 23  High school diploma (Abitur or equivalent)     Both
# 26                                         Phd  Working
# 27                             Master's degree     Both
# 28                           Bachelor's degree     Both
# 29                             Master's degree  Working
#
#                                           study_field  study_year  \
# 0                                 Data Science (M.Sc)      2026.0
# 1                   Computer-aided design (CAD) (B.A)         5.0
# 2                                  Informatik (B.Sc.)         4.0
# 3                                                None         NaN
# 5                                                None         NaN
# 6                                                None         NaN
# 9                                                None         NaN
# 10                                               None         NaN
# 11                                               None         NaN
# 14                                   Computer Science         4.0
# 15                                               None         NaN
# 17  Remote Sensing, GeoInformation and Visualisati...         6.0
# 20             Theoretical physics, Cosmology (Ph.D.)        10.0
# 21                                               None         NaN
# 22                                     Remote Sensing         6.0
# 23                            Computer Science (B.Sc)         3.0
# 26                                               None         NaN
# 27                            Computer Science (M.Sc)         5.0
# 28                Audiokommunikation und -technologie         8.0
# 29                                               None         NaN
#
#                                            work_field  work_exp_years  ...  \
# 0                  Data engineer in auomotive company             3.0  ...
# 1                                     Computer vision             1.0  ...
# 2                                  Research assistant             1.0  ...
# 3   Immunology research and biomedical analytics s...             6.0  ...
# 5                    Software engineering for the web             6.0  ...
# 6   Research on LLMs for transparency and responsi...             5.0  ...
# 9                                Software Engineering            22.0  ...
# 10          Interface design and Software architeture            20.0  ...
# 11      Software engineering in an e-commerce company            12.0  ...
# 14                               Software engineering             2.0  ...
# 15                                         Researcher             9.0  ...
# 17    Data analysis and visualisation for a newspaper             2.0  ...
# 20  Post Doctoral researcher in cosmology/astrophy...             1.0  ...
# 21         Software developer/Geoinformatics Engineer             0.0  ...
# 22  Project Developer Working Student in Energy In...             1.0  ...
# 23                           Fullstack Webdevelopment             3.0  ...
# 26              Senior NLP researcher at a University             6.0  ...
# 27  Software Engineering intern at a fish louse la...             2.0  ...
# 28                                Radio & digital Art             6.0  ...
# 29                                 Research Associate             3.0  ...
#
#    llms_ethical_concerns llms_ec_bias llms_ec_discrimination  \
# 0                  Agree           No                     No
# 1                  Agree          Yes                     No
# 2                  Agree          Yes                    Yes
# 3                  Agree          Yes                     No
# 5                Neutral         None                   None
# 6                  Agree          Yes                     No
# 9         Strongly Agree          Yes                    Yes
# 10                 Agree           No                     No
# 11        Strongly Agree          Yes                    Yes
# 14                 Agree           No                     No
# 15                  None         None                   None
# 17                  None         None                   None
# 20                 Agree          Yes                    Yes
# 21               Neutral         None                   None
# 22                 Agree          Yes                    Yes
# 23        Strongly Agree          Yes                     No
# 26        Strongly Agree          Yes                    Yes
# 27               Neutral         None                   None
# 28                 Agree          Yes                    Yes
# 29        Strongly Agree          Yes                    Yes
#
#    llms_ec_skill_loss llms_ec_learn_less llms_ec_diversity_loss llms_ec_other  \
# 0                  No                 No                     No           Yes
# 1                 Yes                Yes                     No            No
# 2                 Yes                Yes                    Yes            No
# 3                 Yes                Yes                    Yes            No
# 5                None               None                   None          None
# 6                 Yes                 No                    Yes            No
# 9                 Yes                 No                    Yes           Yes
# 10                Yes                 No                     No            No
# 11                Yes                Yes                    Yes            No
# 14                Yes                 No                    Yes            No
# 15               None               None                   None          None
# 17               None               None                   None          None
# 20                 No                 No                     No           Yes
# 21               None               None                   None          None
# 22                 No                 No                    Yes            No
# 23                Yes                Yes                    Yes            No
# 26                Yes                 No                     No            No
# 27               None               None                   None          None
# 28                 No                 No                     No           Yes
# 29                Yes                Yes                    Yes            No
#
#                                   llms_other_concerns  \
# 0     LLMs can use code protected from specific usage
# 1                                                None
# 2                                                None
# 3                                                None
# 5                                                None
# 6                                                None
# 9   LLMs might reduce the motivation to publish kn...
# 10                                               None
# 11                                               None
# 14                                               None
# 15                                               None
# 17                                               None
# 20  Violation of intellectual property, unemployme...
# 21                                               None
# 22                                               None
# 23                                               None
# 26                                               None
# 27                                               None
# 28                             copyright infringement
# 29                                               None
#
#                                   llms_other_thoughts usage_frequency_num
# 0                                                None                   5
# 1                                                None                   4
# 2                                                None                   4
# 3   Programming, problem solving and comprehension...                   5
# 5   It produces a lot of very bad unmaintainable c...                   5
# 6       They might reduce people's creative thinking.                   4
# 9   As a coding assistant, at the current state, L...                   4
# 10                   Too many to write into this box.                   5
# 11                                               None                   2
# 14                                               None                   5
# 15                                               None                   4
# 17                                               None                   4
# 20  LLMs are amazing for speeding up simple/mundan...                   5
# 21                                               None                   5
# 22  If you do something important always be critia...                   5
# 23  Having LLM written code is in my experience al...                   5
# 26  My attention span on long text is not as good ...                   3
# 27  Can be a useful tool, but it's definitely not ...                   4
# 28                                               None                   3
# 29                                               None                   5
#
# [20 rows x 36 columns]

# %%
filtered
# Out:
#     user_id  lastpage        seed    age  \
# 1         8         8  1155338690  19-25
# 2        11         8  1462336171  26-30
# 4        16         8  1979098288  19-25
# 7        29         8   978929840  26-30
# 13       48         8  2031177185  19-25
# 14       55         8  2025687955  26-30
# 16       60         8  1849077149  19-25
# 17       63         3   831754724  26-30
# 18       65         8   151250910  19-25
# 19       73         8   712726586  31-35
# 20       77         8  1057823690  26-30
# 22       81         8   721420406  26-30
# 23       83         8  1653248369  19-25
# 25       88         8  1547460079  19-25
# 27       90         8  2010148169  26-30
# 28       91         8   793167065  31-35
#
#                                      education   status  \
# 1                            Bachelor's degree     Both
# 2                            Bachelor's degree     Both
# 4                            Bachelor's degree  Student
# 7                              Master's degree  Student
# 13                           Bachelor's degree  Student
# 14                           Bachelor's degree     Both
# 16  High school diploma (Abitur or equivalent)  Student
# 17                           Bachelor's degree     Both
# 18                           Bachelor's degree  Student
# 19                           Bachelor's degree  Student
# 20                             Master's degree     Both
# 22                           Bachelor's degree     Both
# 23  High school diploma (Abitur or equivalent)     Both
# 25  High school diploma (Abitur or equivalent)  Student
# 27                             Master's degree     Both
# 28                           Bachelor's degree     Both
#
#                                           study_field  study_year  \
# 1                   Computer-aided design (CAD) (B.A)         5.0
# 2                                  Informatik (B.Sc.)         4.0
# 4                        Computer Engineering (M.Sc.)         2.0
# 7                             PhD in Computer Science         3.0
# 13             Information Systems Management (M.Sc.)         6.0
# 14                                   Computer Science         4.0
# 16                                     Physik (B.Sc.)         5.0
# 17  Remote Sensing, GeoInformation and Visualisati...         6.0
# 18                                    Geoinformation          2.0
# 19                           Computer Science (M.Sc.)         8.0
# 20             Theoretical physics, Cosmology (Ph.D.)        10.0
# 22                                     Remote Sensing         6.0
# 23                            Computer Science (B.Sc)         3.0
# 25                      Wirtschaftsinformatik (B.Sc.)         2.0
# 27                            Computer Science (M.Sc)         5.0
# 28                Audiokommunikation und -technologie         8.0
#
#                                            work_field  work_exp_years  ...  \
# 1                                     Computer vision             1.0  ...
# 2                                  Research assistant             1.0  ...
# 4                                                None             NaN  ...
# 7                                                None             NaN  ...
# 13                                               None             NaN  ...
# 14                               Software engineering             2.0  ...
# 16                                               None             NaN  ...
# 17    Data analysis and visualisation for a newspaper             2.0  ...
# 18                                               None             NaN  ...
# 19                                               None             NaN  ...
# 20  Post Doctoral researcher in cosmology/astrophy...             1.0  ...
# 22  Project Developer Working Student in Energy In...             1.0  ...
# 23                           Fullstack Webdevelopment             3.0  ...
# 25                                               None             NaN  ...
# 27  Software Engineering intern at a fish louse la...             2.0  ...
# 28                                Radio & digital Art             6.0  ...
#
#    llms_ethical_concerns llms_ec_bias llms_ec_discrimination  \
# 1                  Agree          Yes                     No
# 2                  Agree          Yes                    Yes
# 4                  Agree          Yes                    Yes
# 7                  Agree          Yes                     No
# 13        Strongly Agree          Yes                    Yes
# 14                 Agree           No                     No
# 16        Strongly Agree          Yes                    Yes
# 17                  None         None                   None
# 18                 Agree           No                     No
# 19                 Agree          Yes                    Yes
# 20                 Agree          Yes                    Yes
# 22                 Agree          Yes                    Yes
# 23        Strongly Agree          Yes                     No
# 25                 Agree           No                     No
# 27               Neutral         None                   None
# 28                 Agree          Yes                    Yes
#
#    llms_ec_skill_loss llms_ec_learn_less llms_ec_diversity_loss llms_ec_other  \
# 1                 Yes                Yes                     No            No
# 2                 Yes                Yes                    Yes            No
# 4                  No                 No                    Yes            No
# 7                  No                Yes                    Yes            No
# 13                Yes                 No                    Yes            No
# 14                Yes                 No                    Yes            No
# 16                Yes                 No                    Yes            No
# 17               None               None                   None          None
# 18                Yes                 No                    Yes            No
# 19                Yes                Yes                     No            No
# 20                 No                 No                     No           Yes
# 22                 No                 No                    Yes            No
# 23                Yes                Yes                    Yes            No
# 25                Yes                Yes                    Yes            No
# 27               None               None                   None          None
# 28                 No                 No                     No           Yes
#
#                                   llms_other_concerns  \
# 1                                                None
# 2                                                None
# 4                                                None
# 7                                                None
# 13                                               None
# 14                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Violation of intellectual property, unemployme...
# 22                                               None
# 23                                               None
# 25                                               None
# 27                                               None
# 28                             copyright infringement
#
#                                   llms_other_thoughts study_year_group
# 1                                                None              3-5
# 2                                                None              3-5
# 4   Sometimes when I am in a hurry I don´t check p...              1-3
# 7                                                None              1-3
# 13  - tbh it accelerates processes a lot\n- LLMs m...             5-10
# 14                                               None              3-5
# 16                                               None              3-5
# 17                                               None             5-10
# 18  From a beginner’s perspective it’s temping to ...              1-3
# 19  I fear that this will lead to more stress in t...             5-10
# 20  LLMs are amazing for speeding up simple/mundan...             5-10
# 22  If you do something important always be critia...             5-10
# 23  Having LLM written code is in my experience al...              1-3
# 25  Carelessly using LLMs might introduce dangerou...              1-3
# 27  Can be a useful tool, but it's definitely not ...              3-5
# 28                                               None             5-10
#
# [16 rows x 36 columns]
